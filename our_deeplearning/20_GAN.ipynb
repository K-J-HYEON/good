# %% [markdown]
# <a href="https://colab.research.google.com/github/K-J-HYEON/good/blob/add-input-method/20_GAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#-*- coding: utf-8 -*-

from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

#이미지가 저장될 폴더가 없다면 만듭니다.
import os 
if not os.path.exists("./gan_images"):
    os.makedirs("./gan_images")

np.random.seed(3) #tensorflow에서 랜덤하게 값 추출
tf.random.set_seed(3)

#생성자 모델을 만듭니다.
generator = Sequential() #모델 이름을 generator로 정하고 Sequential()함수를 호출
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2))) # 128은 임의로 정한 노드의 수 
# input_dim은 랜덤 백터를 준비해 집어넣으라는 뜻이다. 적절한 숫자를 임의로 넣어주면 된다.(100차원 크기의 랜덤 벡터를 준비해 집어넣으라는 뜻이다.)
# ReLU와 거의 비슷한 형태를 갖습니다. 입력 값이 음수일 때 완만한 선형 함수를 그려줍니다.
# https://leestation.tistory.com/776참고
# ReLU 함수는 x≦0일 때 경사가 사라져버려 학습 과정이 불안해질 수 있는 문제가 있었지만 LReLU는 x≦0일 때도 학습이 진행되기 때문에 
# ReLU 함수보다 효과적인 활성화 함수라고 생각할 수 있지만 
# 실제로 사용하게 되면 효과가 있는 경우도 있고, 없는 경우도 있어 언제 효과가 나타나는지에 관해 아직 밝혀진 바가 없다.


generator.add(BatchNormalization()) #배치정규화 과정 : 입력 데이터의 평균이 0, 분산이 1이 되도록 재배치하는 것인데, 
# 값을 일정하게 재배치하는 역할을 한다.=> 층의 개수가 늘어나도 안정적인 학습을 진행할 수 있다.
generator.add(Reshape((7, 7, 128)))  #컨볼루션 레이어가 받아들일 수 있는 형태로 바꾸어 주는 코드
# Conv2D()함수의 input_shape부분에 들어갈 형태로 정해 준다.

generator.add(UpSampling2D()) # 14 * 14의 이미지로 바뀐다. 즉, 이미지의 가로, 세로 크기를 2배씩 늘려준다.(this layer를 지나면서 크기가 14 * 14가 되고)
generator.add(Conv2D(64, kernel_size=5, padding='same')) # 커널 사이즈는 5 * 5짜리 필터를 사용하겠다.
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2))) #p.284 참고 0보다 작을경우 0.2를 곱하라(GAN에서는 기존 랠루함수를 쓰면 학습이 불안정해 지는 경우가 많아서 리키랠루를쓴다) 
generator.add(UpSampling2D())#(this layer를 지나면서 크기가 28 * 28이 된다)

generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))
#노드 1개 /5*5커널 만들고 /제로패딩 해준다음/ 탄젠트 함수를 쓴다.

#판별자 모델을 만듭니다.
discriminator = Sequential() #시퀀셜 함수 호출
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same")) #노드 수 64개  5*5커널이 쓰이고 
# stride는 커널 윈도를 몇 칸씩 이동시킬지를 정하는 옵션(여러 칸 움직이게 하는 이유는 => 가로, 세로 크기가 더 줄어 들어 새로운 특징을 추출해준다.(드롭아웃이나 풀링처럼 새로운 필터를 적용한 효과)
#input_shape (행, 열, 색상=3 or 흑백=1) #맨 처음 층에는 입력되는 값을 알려주어야 한다.

# filters: 몇 개의 다른 종류의 필터를 활용할 것인지를 나타냄. 출력 모양의 깊이(depth) 를 결정한다.
# kernel_size: 연산을 수행할 때 윈도우의 크기를 의미한다.
# strides: 연산을 수행할 때 윈도우가 가로 그리고 세로로 움직이면서 내적 연산을 수행하는데, 한 번에 얼마나 움직일지를 의미한다.


discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
#판별자는 진짜와 가짜만 구분하면 되기 때문에 생성자에서처럼 upsampling을 사용하지 않고 stride나 dropout을 통해서 차원을 줄여주는 기능을 적극적으로 사용하면서
#컨볼루션 신경망 본래의 목적을 달성하면 된다.

discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same")) #노드 수 128개  5*5커널이 쓰이고
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())#1차원으로 만들어주고 (가로 * 세로의 2차원으로 진행된 과정을 1차원으로 바꾸어 주는 flatten()함수와)
discriminator.add(Dense(1, activation='sigmoid')) # 마지막 활성화 함수로 sigmoid() 사용
discriminator.compile(loss='binary_crossentropy', optimizer='adam')

discriminator.trainable = False #판별자가 진짜냐 가짜냐 판별만 하게끔
#(판별자는 가져 온 모델을 가지고 판별만 하고 판별자 자신이 학습되지 않게끔)

# %%
#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))#랜덤한 100개의 벡터를 케라스의 Input() 함수에 집어넣어서 생성자에 입력할 ginput을 만든다.
dis_output = discriminator(generator(ginput)) # 생성자 모델 generator()에 ginput을 입력한다. 
#그 결과 출력되는 28 * 28크기의 이미지가 그대로 판별자 모델 discriminator()입력값으로 들어감
#판별자는 이 인풋값으로 참과 거짓을 판별하는데 그 결과를 dis_output이라 한다.

gan = Model(ginput, dis_output) #keras의 model함수 이용해 ginput값과 위에 dus_output값을 넣어서 gan이라는 이름의 새로운 모델 만듬.
gan.compile(loss='binary_crossentropy', optimizer='adam')#이진 로스 함수와 아담 옵티마이저를 사용해서 gen모델을 compile한다.(컴퓨터가 번역하게 끔)
gan.summary()


#신경망을 실행시키는 함수를 만듭니다. (지금까지의 모든과정을 실행시킴)
def gan_train(epoch, batch_size, saving_interval):#gan_train이란 함수를 통해 학습을 진행(saving_interval = 중간 과정을 저장할 때 몇 번마다 한 번씩 저장할지 정하는)
    # / / 어느 구간에 저장할 saving 타이밍

  # MNIST 데이터 불러오기(손글씨 데이터)

  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 


 # 단, 테스트과정은 필요없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')#가로 28, 세로 28 픽셀이고 흑백이므로 1을 설정

  X_train = (X_train - 127.5) / 127.5  

  # 픽셀값은 0에서 255사이의 값입니다. 이전에 255로 나누어 줄때는 
  # 이를 0~1사이의 값으로 바꾸었던 것인데, 
  # 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  # X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1)) #모두 참(1)이라는 레이블 값을 가진 배열을 만든다.
  fake = np.zeros((batch_size, 1)) #모두 가짜(0)이라는 레이블 값을 가진 열을 batch_size 길이만큼 만든다.

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)#numpy 라이브러리 random() 함수를 사용해서 실제 이미지를 랜덤하게 선택해서 불러온다.
          #np.random.randint(a, b, c)는 a부터 b까지의 숫자 중 하나를 랜덤하게 선택해 가져오는 과정을 c번 반복하라는 뜻 0부터 X_train 개수 사이의 숫자를 배치사이즈 만큼 반복해서 가져오겠다.
          #batch_size는 한 번에 몇 개의 실제 이미지와 몇 개의 가상 이미지를 판별자에 넣을지 결정하는 변수 
          # train데이터의 전체 데이터 배치 사이즈 만큼 추출 하겠다. = index
          imgs = X_train[idx] #위에서 선택된 idx에 해당하는 이미지를 불러온다
          d_loss_real = discriminator.train_on_batch(imgs, true) #위에서 정한 true만큼 batch_size 길이만큼 만든다. 
          #판별자 모델에 train_on_batch() 함수를 써서 판별을 시작한다. 
          #ex)train_on_batch(x, y)함수는 입력 값(x)과 레이블(y)을 받아서 딱 한 번 학습을 실시해 모델을 업데이트 한다.
                #즉 x에는 imgs y에는 true를 넣고 준비를 마친다.

          # 배치사이즈를 트루로 인식하겠다 
        #이미지와 레이블  = imgs, true



          #가상 이미지를 판별자에 입력하는 부분입니다.
          #학습이 반복될수록 가짜라는 레이블을 붙인 이미지들에 대한 예측 결과가 거짓으로 나온다.
          noise = np.random.normal(0, 1, (batch_size, 100)) #생성자에 집어넣을 가상 이미지
          # 정수가 아니기 때문에 np.random.normal() 함수를 사용했는데
          # 여기서 (batch_size,100)은 batch_size만큼 100열을 뽑으라는 의미

          gen_imgs = generator.predict(noise)#noise가 생성자에 들어가고 결괏값이 gen_imgs로 저장된다.
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake) #gen_imgs에 fake(모두가짜(0))라는 레이블이 붙는다.
          # gen_imgs한테 fake라고 학습을 시키는 과정
            

          #판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake) #d_loss_real과 d_loss_fake를 더해서 둘로 나눈 평균이 판별차의 오차

          g_loss = gan.train_on_batch(noise, true) #판별자와 생성자를 연결해서 만든 gan 모델을 이용해 생성자의 오차, g_loss를 구한다.
          #train_on_batch() 함수와 앞서 만든 gen_imgs를 사용한다. 생성자의 레이블은 무조건 참(1) 해놓고 판별자로 넘긴다.

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss) #학습이 진행되는 동안 생성자와 판별자의 오차가 출력된다.


        # 이부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 본 장의 주요 내용과 관련이 없어
        # 소스코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100)) #0, 1 사이에서 25~100까지
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("gan_images/gan_mnist_%d.png" % i)

gan_train(4001, 32, 200)  #4000번 반복되고(+1을 해 주는 것에 주의), 배치 사이즈는 32,  200번 마다 결과가 저장되게 하였습니다.
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential_2 (Sequential)    (None, 28, 28, 1)         865281
# _________________________________________________________________
# sequential_3 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# epoch:0  d_loss:0.7053  g_loss:0.6912
# epoch:1  d_loss:0.4617  g_loss:0.3278
# epoch:2  d_loss:0.5702  g_loss:0.1026
# epoch:3  d_loss:0.6598  g_loss:0.0842
# epoch:4  d_loss:0.5770  g_loss:0.1651
# epoch:5  d_loss:0.5089  g_loss:0.4225
# epoch:6  d_loss:0.4875  g_loss:0.6988
# epoch:7  d_loss:0.5093  g_loss:0.8724
# epoch:8  d_loss:0.4981  g_loss:0.8938
# epoch:9  d_loss:0.4892  g_loss:0.8643
# epoch:10  d_loss:0.4208  g_loss:0.7685
# epoch:11  d_loss:0.4503  g_loss:0.7971
# epoch:12  d_loss:0.5066  g_loss:0.8361
# epoch:13  d_loss:0.5006  g_loss:0.8596
# epoch:14  d_loss:0.5893  g_loss:0.9348
# epoch:15  d_loss:0.4858  g_loss:1.0207
# epoch:16  d_loss:0.4194  g_loss:1.0283
# epoch:17  d_loss:0.6258  g_loss:0.8232
# epoch:18  d_loss:0.5484  g_loss:0.6581
# epoch:19  d_loss:0.4573  g_loss:0.7167
# epoch:20  d_loss:0.4386  g_loss:0.7397
# epoch:21  d_loss:0.4987  g_loss:0.7843
# epoch:22  d_loss:0.4976  g_loss:0.6481
# epoch:23  d_loss:0.4532  g_loss:0.5917
# epoch:24  d_loss:0.4374  g_loss:0.6483
# epoch:25  d_loss:0.4569  g_loss:0.6611
# epoch:26  d_loss:0.4924  g_loss:0.6744
# epoch:27  d_loss:0.4387  g_loss:0.5833
# epoch:28  d_loss:0.4504  g_loss:0.5371
# epoch:29  d_loss:0.4847  g_loss:0.5343
# epoch:30  d_loss:0.4128  g_loss:0.5951
# epoch:31  d_loss:0.4109  g_loss:0.7209
# epoch:32  d_loss:0.3624  g_loss:0.5869
# epoch:33  d_loss:0.3230  g_loss:0.7689
# epoch:34  d_loss:0.2538  g_loss:0.7779
# epoch:35  d_loss:0.3019  g_loss:0.8354
# epoch:36  d_loss:0.3089  g_loss:0.6987
# epoch:37  d_loss:0.2534  g_loss:0.9188
# epoch:38  d_loss:0.2641  g_loss:0.9874
# epoch:39  d_loss:0.1663  g_loss:1.3411
# epoch:40  d_loss:0.2553  g_loss:1.2566
# epoch:41  d_loss:0.3296  g_loss:0.8411
# epoch:42  d_loss:0.3606  g_loss:0.6674
# epoch:43  d_loss:0.2839  g_loss:0.7618
# epoch:44  d_loss:0.2500  g_loss:1.1516
# epoch:45  d_loss:0.3889  g_loss:1.5130
# epoch:46  d_loss:0.7135  g_loss:1.0981
# epoch:47  d_loss:0.2996  g_loss:1.6254
# epoch:48  d_loss:0.0981  g_loss:2.3560
# epoch:49  d_loss:0.0837  g_loss:2.6920
# epoch:50  d_loss:0.0382  g_loss:2.6832
# epoch:51  d_loss:0.0589  g_loss:3.2390
# epoch:52  d_loss:0.0758  g_loss:3.1167
# epoch:53  d_loss:0.2373  g_loss:2.7117
# epoch:54  d_loss:0.3411  g_loss:3.5912
# epoch:55  d_loss:0.4146  g_loss:3.4612
# epoch:56  d_loss:0.6752  g_loss:2.0673
# epoch:57  d_loss:0.9242  g_loss:2.2871
# epoch:58  d_loss:0.6549  g_loss:2.9138
# epoch:59  d_loss:0.5492  g_loss:2.8081
# epoch:60  d_loss:0.4689  g_loss:2.7083
# epoch:61  d_loss:0.3737  g_loss:2.8192
# epoch:62  d_loss:0.3038  g_loss:3.4561
# epoch:63  d_loss:0.1837  g_loss:3.9387
# epoch:64  d_loss:0.5235  g_loss:3.0218
# epoch:65  d_loss:0.4657  g_loss:2.4067
# epoch:66  d_loss:0.6026  g_loss:1.5322
# epoch:67  d_loss:0.4717  g_loss:2.1774
# epoch:68  d_loss:0.2092  g_loss:3.7642
# epoch:69  d_loss:0.7819  g_loss:2.0788
# epoch:70  d_loss:1.0353  g_loss:0.8182
# epoch:71  d_loss:0.4947  g_loss:0.9387
# epoch:72  d_loss:0.7214  g_loss:1.1554
# epoch:73  d_loss:0.5668  g_loss:1.6886
# epoch:74  d_loss:0.8463  g_loss:1.6343
# epoch:75  d_loss:0.8065  g_loss:1.2587
# epoch:76  d_loss:0.6839  g_loss:1.1658
# epoch:77  d_loss:0.4476  g_loss:1.9928
# epoch:78  d_loss:0.3317  g_loss:3.3135
# epoch:79  d_loss:0.2614  g_loss:3.8648
# epoch:80  d_loss:0.2873  g_loss:3.5088
# epoch:81  d_loss:0.3800  g_loss:3.1719
# epoch:82  d_loss:0.3697  g_loss:3.0818
# epoch:83  d_loss:0.2759  g_loss:4.2544
# epoch:84  d_loss:0.3541  g_loss:4.5685
# epoch:85  d_loss:0.9872  g_loss:3.7116
# epoch:86  d_loss:0.7250  g_loss:3.6366
# epoch:87  d_loss:0.8394  g_loss:3.9828
# epoch:88  d_loss:1.0350  g_loss:2.9014
# epoch:89  d_loss:0.8944  g_loss:2.7524
# epoch:90  d_loss:0.7502  g_loss:2.6563
# epoch:91  d_loss:0.7227  g_loss:2.6549
# epoch:92  d_loss:0.8586  g_loss:2.1979
# epoch:93  d_loss:0.8341  g_loss:2.2604
# epoch:94  d_loss:0.5855  g_loss:1.8284
# epoch:95  d_loss:0.5297  g_loss:1.5617
# epoch:96  d_loss:0.5152  g_loss:1.6656
# epoch:97  d_loss:0.4494  g_loss:1.3922
# epoch:98  d_loss:0.4519  g_loss:1.4159
# epoch:99  d_loss:0.4860  g_loss:1.2878
# epoch:100  d_loss:0.5059  g_loss:1.2905
# epoch:101  d_loss:0.4008  g_loss:1.3364
# epoch:102  d_loss:0.3968  g_loss:1.2489
# epoch:103  d_loss:0.4733  g_loss:1.3612
# epoch:104  d_loss:0.3820  g_loss:1.2228
# epoch:105  d_loss:0.4293  g_loss:0.9658
# epoch:106  d_loss:0.4883  g_loss:0.9290
# epoch:107  d_loss:0.4008  g_loss:0.9785
# epoch:108  d_loss:0.4354  g_loss:0.9445
# epoch:109  d_loss:0.3790  g_loss:0.9113
# epoch:110  d_loss:0.4237  g_loss:0.9863
# epoch:111  d_loss:0.3965  g_loss:1.3721
# epoch:112  d_loss:0.3997  g_loss:1.3914
# epoch:113  d_loss:0.5138  g_loss:1.1134
# epoch:114  d_loss:0.6246  g_loss:0.8466
# epoch:115  d_loss:0.5408  g_loss:0.7987
# epoch:116  d_loss:0.5858  g_loss:0.7537
# epoch:117  d_loss:0.4981  g_loss:0.8222
# epoch:118  d_loss:0.5448  g_loss:0.9155
# epoch:119  d_loss:0.4522  g_loss:1.1736
# epoch:120  d_loss:0.5595  g_loss:1.2165
# epoch:121  d_loss:0.6009  g_loss:1.3341
# epoch:122  d_loss:0.7151  g_loss:1.1812
# epoch:123  d_loss:0.6387  g_loss:1.0403
# epoch:124  d_loss:0.5382  g_loss:1.0352
# epoch:125  d_loss:0.6589  g_loss:1.1263
# epoch:126  d_loss:0.5366  g_loss:1.2115
# epoch:127  d_loss:0.3999  g_loss:1.6603
# epoch:128  d_loss:0.3984  g_loss:1.8087
# epoch:129  d_loss:0.3497  g_loss:2.0853
# epoch:130  d_loss:0.4055  g_loss:1.8683
# epoch:131  d_loss:0.3893  g_loss:1.8585
# epoch:132  d_loss:0.3348  g_loss:1.8454
# epoch:133  d_loss:0.3382  g_loss:1.8087
# epoch:134  d_loss:0.3440  g_loss:1.8948
# epoch:135  d_loss:0.2257  g_loss:2.8334
# epoch:136  d_loss:0.3743  g_loss:2.5800
# epoch:137  d_loss:0.3217  g_loss:2.2847
# epoch:138  d_loss:0.3201  g_loss:2.2063
# epoch:139  d_loss:0.3536  g_loss:2.3552
# epoch:140  d_loss:0.5267  g_loss:2.0250
# epoch:141  d_loss:0.4328  g_loss:2.1270
# epoch:142  d_loss:0.6131  g_loss:2.2892
# epoch:143  d_loss:0.5188  g_loss:2.4899
# epoch:144  d_loss:0.6343  g_loss:2.2741
# epoch:145  d_loss:0.7063  g_loss:1.6914
# epoch:146  d_loss:0.5881  g_loss:2.2518
# epoch:147  d_loss:0.8599  g_loss:2.0641
# epoch:148  d_loss:0.7871  g_loss:1.6146
# epoch:149  d_loss:0.6535  g_loss:1.8426
# epoch:150  d_loss:0.6670  g_loss:1.6837
# epoch:151  d_loss:0.7283  g_loss:1.6846
# epoch:152  d_loss:0.6464  g_loss:1.4977
# epoch:153  d_loss:0.6316  g_loss:1.4936
# epoch:154  d_loss:0.4973  g_loss:1.3733
# epoch:155  d_loss:0.5521  g_loss:1.5532
# epoch:156  d_loss:0.5817  g_loss:1.6323
# epoch:157  d_loss:0.5014  g_loss:1.8195
# epoch:158  d_loss:0.4525  g_loss:1.7878
# epoch:159  d_loss:0.3683  g_loss:1.9883
# epoch:160  d_loss:0.4229  g_loss:1.7705
# epoch:161  d_loss:0.3911  g_loss:2.0503
# epoch:162  d_loss:0.3587  g_loss:1.7022
# epoch:163  d_loss:0.3249  g_loss:1.8636
# epoch:164  d_loss:0.3335  g_loss:1.9229
# epoch:165  d_loss:0.2497  g_loss:2.1445
# epoch:166  d_loss:0.3136  g_loss:2.2674
# epoch:167  d_loss:0.3375  g_loss:2.1459
# epoch:168  d_loss:0.3349  g_loss:1.8380
# epoch:169  d_loss:0.4598  g_loss:1.9283
# epoch:170  d_loss:0.3807  g_loss:1.6305
# epoch:171  d_loss:0.4225  g_loss:1.5455
# epoch:172  d_loss:0.3385  g_loss:1.6473
# epoch:173  d_loss:0.3260  g_loss:1.6476
# epoch:174  d_loss:0.4604  g_loss:1.7012
# epoch:175  d_loss:0.3538  g_loss:1.9860
# epoch:176  d_loss:0.5446  g_loss:1.8143
# epoch:177  d_loss:0.5361  g_loss:1.5251
# epoch:178  d_loss:0.3869  g_loss:1.5151
# epoch:179  d_loss:0.5323  g_loss:1.1841
# epoch:180  d_loss:0.5682  g_loss:1.1597
# epoch:181  d_loss:0.5447  g_loss:1.3752
# epoch:182  d_loss:0.6203  g_loss:1.4917
# epoch:183  d_loss:0.6198  g_loss:1.5920
# epoch:184  d_loss:0.5235  g_loss:1.2988
# epoch:185  d_loss:0.7202  g_loss:1.2217
# epoch:186  d_loss:0.6300  g_loss:1.1579
# epoch:187  d_loss:0.6503  g_loss:1.1692
# epoch:188  d_loss:0.7214  g_loss:1.1888
# epoch:189  d_loss:0.5991  g_loss:1.1371
# epoch:190  d_loss:0.5707  g_loss:1.1245
# epoch:191  d_loss:0.6322  g_loss:1.2605
# epoch:192  d_loss:0.5303  g_loss:1.4783
# epoch:193  d_loss:0.6699  g_loss:1.1245
# epoch:194  d_loss:0.5178  g_loss:1.3726
# epoch:195  d_loss:0.4654  g_loss:1.3135
# epoch:196  d_loss:0.4396  g_loss:1.4190
# epoch:197  d_loss:0.3859  g_loss:1.5585
# epoch:198  d_loss:0.3266  g_loss:2.0753
# epoch:199  d_loss:0.3466  g_loss:2.0672
# epoch:200  d_loss:0.4434  g_loss:1.9934
# epoch:201  d_loss:0.4048  g_loss:1.5797
# epoch:202  d_loss:0.4938  g_loss:1.6962
# epoch:203  d_loss:0.2827  g_loss:1.9659
# epoch:204  d_loss:0.3832  g_loss:2.2735
# epoch:205  d_loss:0.2889  g_loss:2.3782
# epoch:206  d_loss:0.3206  g_loss:2.3265
# epoch:207  d_loss:0.3362  g_loss:2.4573
# epoch:208  d_loss:0.4748  g_loss:2.1744
# epoch:209  d_loss:0.3890  g_loss:1.9188
# epoch:210  d_loss:0.6021  g_loss:1.8231
# epoch:211  d_loss:0.5121  g_loss:2.1708
# epoch:212  d_loss:0.5020  g_loss:2.6292
# epoch:213  d_loss:0.5650  g_loss:2.6893
# epoch:214  d_loss:0.6131  g_loss:1.7419
# epoch:215  d_loss:0.5759  g_loss:1.6451
# epoch:216  d_loss:0.5611  g_loss:1.6806
# epoch:217  d_loss:0.4476  g_loss:1.4180
# epoch:218  d_loss:0.4416  g_loss:1.7989
# epoch:219  d_loss:0.5335  g_loss:1.5214
# epoch:220  d_loss:0.5102  g_loss:1.8805
# epoch:221  d_loss:0.5362  g_loss:1.6161
# epoch:222  d_loss:0.5535  g_loss:1.5293
# epoch:223  d_loss:0.4809  g_loss:1.6829
# epoch:224  d_loss:0.5093  g_loss:1.4791
# epoch:225  d_loss:0.4956  g_loss:1.3792
# epoch:226  d_loss:0.4575  g_loss:1.3040
# epoch:227  d_loss:0.5374  g_loss:1.7515
# epoch:228  d_loss:0.4870  g_loss:1.8684
# epoch:229  d_loss:0.4444  g_loss:1.7203
# epoch:230  d_loss:0.5699  g_loss:1.8156
# epoch:231  d_loss:0.6188  g_loss:1.6919
# epoch:232  d_loss:0.6264  g_loss:1.6230
# epoch:233  d_loss:0.5384  g_loss:1.6540
# epoch:234  d_loss:0.5506  g_loss:1.4869
# epoch:235  d_loss:0.5458  g_loss:1.2449
# epoch:236  d_loss:0.5282  g_loss:1.3612
# epoch:237  d_loss:0.4225  g_loss:1.7510
# epoch:238  d_loss:0.4803  g_loss:2.0445
# epoch:239  d_loss:0.3880  g_loss:2.1044
# epoch:240  d_loss:0.5211  g_loss:1.9151
# epoch:241  d_loss:0.6171  g_loss:1.9947
# epoch:242  d_loss:0.5054  g_loss:1.8040
# epoch:243  d_loss:0.5303  g_loss:1.6298
# epoch:244  d_loss:0.4391  g_loss:1.8141
# epoch:245  d_loss:0.3898  g_loss:1.8486
# epoch:246  d_loss:0.4861  g_loss:2.0927
# epoch:247  d_loss:0.5055  g_loss:2.6493
# epoch:248  d_loss:0.4001  g_loss:2.3679
# epoch:249  d_loss:0.5226  g_loss:2.1392
# epoch:250  d_loss:0.4474  g_loss:1.7864
# epoch:251  d_loss:0.4178  g_loss:2.1175
# epoch:252  d_loss:0.3758  g_loss:1.9377
# epoch:253  d_loss:0.5116  g_loss:1.9901
# epoch:254  d_loss:0.4764  g_loss:2.3622
# epoch:255  d_loss:0.5643  g_loss:2.4312
# epoch:256  d_loss:0.5636  g_loss:2.6452
# epoch:257  d_loss:0.4137  g_loss:1.9293
# epoch:258  d_loss:0.5493  g_loss:1.9453
# epoch:259  d_loss:0.4782  g_loss:2.1087
# epoch:260  d_loss:0.5707  g_loss:2.1410
# epoch:261  d_loss:0.3570  g_loss:2.1149
# epoch:262  d_loss:0.4231  g_loss:2.4525
# epoch:263  d_loss:0.4742  g_loss:2.0431
# epoch:264  d_loss:0.6585  g_loss:1.5649
# epoch:265  d_loss:0.5165  g_loss:2.1456
# epoch:266  d_loss:0.3317  g_loss:2.6981
# epoch:267  d_loss:0.4150  g_loss:3.2080
# epoch:268  d_loss:0.4390  g_loss:2.4763
# epoch:269  d_loss:0.5136  g_loss:1.7926
# epoch:270  d_loss:0.4125  g_loss:1.6577
# epoch:271  d_loss:0.2793  g_loss:2.0299
# epoch:272  d_loss:0.3311  g_loss:2.7281
# epoch:273  d_loss:0.3948  g_loss:3.3767
# epoch:274  d_loss:0.4712  g_loss:2.2216
# epoch:275  d_loss:0.4350  g_loss:2.1892
# epoch:276  d_loss:0.3673  g_loss:2.2715
# epoch:277  d_loss:0.3612  g_loss:2.4642
# epoch:278  d_loss:0.2553  g_loss:2.5658
# epoch:279  d_loss:0.3521  g_loss:2.6475
# epoch:280  d_loss:0.2733  g_loss:2.5503
# epoch:281  d_loss:0.3626  g_loss:2.8615
# epoch:282  d_loss:0.3083  g_loss:2.4862
# epoch:283  d_loss:0.2920  g_loss:2.9204
# epoch:284  d_loss:0.3941  g_loss:2.6404
# epoch:285  d_loss:0.3238  g_loss:2.4175
# epoch:286  d_loss:0.2419  g_loss:2.8480
# epoch:287  d_loss:0.2843  g_loss:2.7750
# epoch:288  d_loss:0.2354  g_loss:3.3284
# epoch:289  d_loss:0.5055  g_loss:2.5826
# epoch:290  d_loss:0.3023  g_loss:2.2589
# epoch:291  d_loss:0.4142  g_loss:2.2044
# epoch:292  d_loss:0.4202  g_loss:2.5902
# epoch:293  d_loss:0.3621  g_loss:3.0530
# epoch:294  d_loss:0.3327  g_loss:3.1294
# epoch:295  d_loss:0.4977  g_loss:2.5107
# epoch:296  d_loss:0.6328  g_loss:1.9979
# epoch:297  d_loss:0.7099  g_loss:1.9987
# epoch:298  d_loss:0.6763  g_loss:1.9597
# epoch:299  d_loss:0.4866  g_loss:2.2113
# epoch:300  d_loss:0.6413  g_loss:1.9262
# epoch:301  d_loss:0.7479  g_loss:1.8579
# epoch:302  d_loss:0.5199  g_loss:2.0216
# epoch:303  d_loss:0.5317  g_loss:1.6078
# epoch:304  d_loss:0.6340  g_loss:1.4763
# epoch:305  d_loss:0.5776  g_loss:1.5730
# epoch:306  d_loss:0.5087  g_loss:1.0964
# epoch:307  d_loss:0.5842  g_loss:1.4101
# epoch:308  d_loss:0.4822  g_loss:1.6720
# epoch:309  d_loss:0.5423  g_loss:1.5850
# epoch:310  d_loss:0.6428  g_loss:1.6388
# epoch:311  d_loss:0.4572  g_loss:1.5655
# epoch:312  d_loss:0.5522  g_loss:1.2858
# epoch:313  d_loss:0.5316  g_loss:1.3644
# epoch:314  d_loss:0.4890  g_loss:1.4228
# epoch:315  d_loss:0.4515  g_loss:1.7377
# epoch:316  d_loss:0.4411  g_loss:1.7762
# epoch:317  d_loss:0.3729  g_loss:1.9521
# epoch:318  d_loss:0.4719  g_loss:1.8124
# epoch:319  d_loss:0.4896  g_loss:1.6957
# epoch:320  d_loss:0.4389  g_loss:1.8830
# epoch:321  d_loss:0.5239  g_loss:1.5020
# epoch:322  d_loss:0.3807  g_loss:1.6760
# epoch:323  d_loss:0.3804  g_loss:2.0549
# epoch:324  d_loss:0.3717  g_loss:2.2888
# epoch:325  d_loss:0.3676  g_loss:1.8219
# epoch:326  d_loss:0.5309  g_loss:1.7176
# epoch:327  d_loss:0.4321  g_loss:1.7328
# epoch:328  d_loss:0.2972  g_loss:2.1890
# epoch:329  d_loss:0.3275  g_loss:2.0377
# epoch:330  d_loss:0.3686  g_loss:2.1452
# epoch:331  d_loss:0.2822  g_loss:2.4805
# epoch:332  d_loss:0.4055  g_loss:2.4275
# epoch:333  d_loss:0.2987  g_loss:2.0176
# epoch:334  d_loss:0.3954  g_loss:1.9213
# epoch:335  d_loss:0.4425  g_loss:1.9037
# epoch:336  d_loss:0.3585  g_loss:1.8726
# epoch:337  d_loss:0.2612  g_loss:2.3132
# epoch:338  d_loss:0.3347  g_loss:2.8018
# epoch:339  d_loss:0.3670  g_loss:2.9268
# epoch:340  d_loss:0.2702  g_loss:3.2017
# epoch:341  d_loss:0.4193  g_loss:2.1831
# epoch:342  d_loss:0.3195  g_loss:1.9415
# epoch:343  d_loss:0.2853  g_loss:2.3165
# epoch:344  d_loss:0.3484  g_loss:2.2725
# epoch:345  d_loss:0.2473  g_loss:3.1595
# epoch:346  d_loss:0.5745  g_loss:2.4262
# epoch:347  d_loss:0.2958  g_loss:2.3705
# epoch:348  d_loss:0.3427  g_loss:2.6928
# epoch:349  d_loss:0.3691  g_loss:2.5646
# epoch:350  d_loss:0.3542  g_loss:3.0024
# epoch:351  d_loss:0.3595  g_loss:2.9922
# epoch:352  d_loss:0.4126  g_loss:2.3560
# epoch:353  d_loss:0.4142  g_loss:1.9881
# epoch:354  d_loss:0.5570  g_loss:1.6814
# epoch:355  d_loss:0.4789  g_loss:2.0795
# epoch:356  d_loss:0.4881  g_loss:2.4525
# epoch:357  d_loss:0.3403  g_loss:3.1919
# epoch:358  d_loss:0.3502  g_loss:3.0389
# epoch:359  d_loss:0.2823  g_loss:3.3206
# epoch:360  d_loss:0.4051  g_loss:2.4336
# epoch:361  d_loss:0.5156  g_loss:2.5463
# epoch:362  d_loss:0.2644  g_loss:2.3756
# epoch:363  d_loss:0.4026  g_loss:2.4616
# epoch:364  d_loss:0.4336  g_loss:2.3999
# epoch:365  d_loss:0.4662  g_loss:2.3783
# epoch:366  d_loss:0.5425  g_loss:2.1814
# epoch:367  d_loss:0.4460  g_loss:2.2636
# epoch:368  d_loss:0.6210  g_loss:1.6267
# epoch:369  d_loss:0.6683  g_loss:1.7522
# epoch:370  d_loss:0.4740  g_loss:2.3962
# epoch:371  d_loss:0.3261  g_loss:2.5993
# epoch:372  d_loss:0.5428  g_loss:2.2792
# epoch:373  d_loss:0.3664  g_loss:1.8313
# epoch:374  d_loss:0.3113  g_loss:1.6627
# epoch:375  d_loss:0.3514  g_loss:1.7424
# epoch:376  d_loss:0.4906  g_loss:1.5218
# epoch:377  d_loss:0.3982  g_loss:2.1999
# epoch:378  d_loss:0.3355  g_loss:2.4993
# epoch:379  d_loss:0.2920  g_loss:2.8196
# epoch:380  d_loss:0.3931  g_loss:2.5997
# epoch:381  d_loss:0.3784  g_loss:2.5581
# epoch:382  d_loss:0.3373  g_loss:1.7773
# epoch:383  d_loss:0.3699  g_loss:1.3284
# epoch:384  d_loss:0.3469  g_loss:1.7571
# epoch:385  d_loss:0.3310  g_loss:1.8811
# epoch:386  d_loss:0.3116  g_loss:2.4027
# epoch:387  d_loss:0.3538  g_loss:2.6030
# epoch:388  d_loss:0.4305  g_loss:1.7549
# epoch:389  d_loss:0.4756  g_loss:1.5895
# epoch:390  d_loss:0.5287  g_loss:1.4981
# epoch:391  d_loss:0.4254  g_loss:1.5475
# epoch:392  d_loss:0.4521  g_loss:1.3630
# epoch:393  d_loss:0.2884  g_loss:1.8566
# epoch:394  d_loss:0.4406  g_loss:1.6038
# epoch:395  d_loss:0.3512  g_loss:2.3443
# epoch:396  d_loss:0.4487  g_loss:2.3125
# epoch:397  d_loss:0.3765  g_loss:2.1957
# epoch:398  d_loss:0.5027  g_loss:1.6532
# epoch:399  d_loss:0.4949  g_loss:1.3401
# epoch:400  d_loss:0.4152  g_loss:1.6825
# epoch:401  d_loss:0.3861  g_loss:1.6871
# epoch:402  d_loss:0.3911  g_loss:2.0714
# epoch:403  d_loss:0.3910  g_loss:1.8859
# epoch:404  d_loss:0.4042  g_loss:2.0344
# epoch:405  d_loss:0.3445  g_loss:1.9522
# epoch:406  d_loss:0.4189  g_loss:1.6179
# epoch:407  d_loss:0.2762  g_loss:2.2416
# epoch:408  d_loss:0.3902  g_loss:1.7505
# epoch:409  d_loss:0.3743  g_loss:2.0254
# epoch:410  d_loss:0.4420  g_loss:1.9901
# epoch:411  d_loss:0.3673  g_loss:1.5197
# epoch:412  d_loss:0.3557  g_loss:1.8823
# epoch:413  d_loss:0.2967  g_loss:2.1270
# epoch:414  d_loss:0.3803  g_loss:2.1231
# epoch:415  d_loss:0.2691  g_loss:2.2098
# epoch:416  d_loss:0.3257  g_loss:2.0459
# epoch:417  d_loss:0.3012  g_loss:2.1176
# epoch:418  d_loss:0.3131  g_loss:2.0069
# epoch:419  d_loss:0.3356  g_loss:2.3006
# epoch:420  d_loss:0.2889  g_loss:2.5970
# epoch:421  d_loss:0.2670  g_loss:2.9767
# epoch:422  d_loss:0.3860  g_loss:2.0978
# epoch:423  d_loss:0.3006  g_loss:2.2501
# epoch:424  d_loss:0.4604  g_loss:1.9093
# epoch:425  d_loss:0.2549  g_loss:2.4803
# epoch:426  d_loss:0.3107  g_loss:2.2439
# epoch:427  d_loss:0.2660  g_loss:2.4067
# epoch:428  d_loss:0.3534  g_loss:2.3085
# epoch:429  d_loss:0.2935  g_loss:2.7064
# epoch:430  d_loss:0.4068  g_loss:2.0507
# epoch:431  d_loss:0.3337  g_loss:2.2852
# epoch:432  d_loss:0.3085  g_loss:2.2787
# epoch:433  d_loss:0.4484  g_loss:2.0239
# epoch:434  d_loss:0.4128  g_loss:1.8070
# epoch:435  d_loss:0.3605  g_loss:2.1213
# epoch:436  d_loss:0.4101  g_loss:2.3949
# epoch:437  d_loss:0.3798  g_loss:2.7301
# epoch:438  d_loss:0.4749  g_loss:1.8728
# epoch:439  d_loss:0.3109  g_loss:1.8245
# epoch:440  d_loss:0.5296  g_loss:1.6468
# epoch:441  d_loss:0.4589  g_loss:1.7062
# epoch:442  d_loss:0.3549  g_loss:2.0390
# epoch:443  d_loss:0.3364  g_loss:2.2094
# epoch:444  d_loss:0.4273  g_loss:1.7601
# epoch:445  d_loss:0.3233  g_loss:2.0330
# epoch:446  d_loss:0.3514  g_loss:1.9024
# epoch:447  d_loss:0.3650  g_loss:2.1539
# epoch:448  d_loss:0.3247  g_loss:2.0521
# epoch:449  d_loss:0.3598  g_loss:1.7770
# epoch:450  d_loss:0.2751  g_loss:1.9731
# epoch:451  d_loss:0.3671  g_loss:2.4146
# epoch:452  d_loss:0.3083  g_loss:2.3290
# epoch:453  d_loss:0.3094  g_loss:2.5369
# epoch:454  d_loss:0.1736  g_loss:2.4293
# epoch:455  d_loss:0.4392  g_loss:2.2896
# epoch:456  d_loss:0.4067  g_loss:2.0996
# epoch:457  d_loss:0.3009  g_loss:2.5286
# epoch:458  d_loss:0.2725  g_loss:2.6800
# epoch:459  d_loss:0.2974  g_loss:3.1925
# epoch:460  d_loss:0.3125  g_loss:2.3007
# epoch:461  d_loss:0.3516  g_loss:2.2450
# epoch:462  d_loss:0.3930  g_loss:1.8717
# epoch:463  d_loss:0.2193  g_loss:2.3173
# epoch:464  d_loss:0.2192  g_loss:2.7076
# epoch:465  d_loss:0.2404  g_loss:2.9626
# epoch:466  d_loss:0.2781  g_loss:2.5695
# epoch:467  d_loss:0.2898  g_loss:2.7970
# epoch:468  d_loss:0.3025  g_loss:1.6374
# epoch:469  d_loss:0.3721  g_loss:1.7843
# epoch:470  d_loss:0.3393  g_loss:2.5831
# epoch:471  d_loss:0.2967  g_loss:2.6533
# epoch:472  d_loss:0.2812  g_loss:2.8940
# epoch:473  d_loss:0.2907  g_loss:2.3456
# epoch:474  d_loss:0.2999  g_loss:2.1407
# epoch:475  d_loss:0.2279  g_loss:2.4109
# epoch:476  d_loss:0.2678  g_loss:2.1643
# epoch:477  d_loss:0.2061  g_loss:2.4198
# epoch:478  d_loss:0.2402  g_loss:2.7645
# epoch:479  d_loss:0.1995  g_loss:2.7119
# epoch:480  d_loss:0.3062  g_loss:1.9505
# epoch:481  d_loss:0.2418  g_loss:2.5824
# epoch:482  d_loss:0.2755  g_loss:2.5423
# epoch:483  d_loss:0.2960  g_loss:2.6463
# epoch:484  d_loss:0.1455  g_loss:3.0732
# epoch:485  d_loss:0.3437  g_loss:2.5895
# epoch:486  d_loss:0.4181  g_loss:2.2588
# epoch:487  d_loss:0.4521  g_loss:1.6725
# epoch:488  d_loss:0.4032  g_loss:2.5331
# epoch:489  d_loss:0.2361  g_loss:2.6616
# epoch:490  d_loss:0.2918  g_loss:2.8449
# epoch:491  d_loss:0.2332  g_loss:2.7838
# epoch:492  d_loss:0.4037  g_loss:2.3556
# epoch:493  d_loss:0.2955  g_loss:2.2468
# epoch:494  d_loss:0.1800  g_loss:2.7176
# epoch:495  d_loss:0.2716  g_loss:3.3093
# epoch:496  d_loss:0.2775  g_loss:2.8596
# epoch:497  d_loss:0.2973  g_loss:2.1491
# epoch:498  d_loss:0.4075  g_loss:1.6292
# epoch:499  d_loss:0.2983  g_loss:1.5409
# epoch:500  d_loss:0.2727  g_loss:2.1116
# epoch:501  d_loss:0.2247  g_loss:2.7157
# epoch:502  d_loss:0.2531  g_loss:2.9267
# epoch:503  d_loss:0.2286  g_loss:3.3365
# epoch:504  d_loss:0.1986  g_loss:3.1845
# epoch:505  d_loss:0.2074  g_loss:2.8841
# epoch:506  d_loss:0.2263  g_loss:2.6777
# epoch:507  d_loss:0.1689  g_loss:2.6812
# epoch:508  d_loss:0.1926  g_loss:2.7707
# epoch:509  d_loss:0.1782  g_loss:3.4356
# epoch:510  d_loss:0.1882  g_loss:3.9962
# epoch:511  d_loss:0.2263  g_loss:3.1200
# epoch:512  d_loss:0.2590  g_loss:2.5906
# epoch:513  d_loss:0.2061  g_loss:2.5139
# epoch:514  d_loss:0.1809  g_loss:3.3875
# epoch:515  d_loss:0.1923  g_loss:3.4746
# epoch:516  d_loss:0.1444  g_loss:3.4988
# epoch:517  d_loss:0.1673  g_loss:2.9676
# epoch:518  d_loss:0.1499  g_loss:3.4095
# epoch:519  d_loss:0.1625  g_loss:2.8403
# epoch:520  d_loss:0.1433  g_loss:2.6554
# epoch:521  d_loss:0.1693  g_loss:2.8360
# epoch:522  d_loss:0.2167  g_loss:2.3160
# epoch:523  d_loss:0.1500  g_loss:4.2663
# epoch:524  d_loss:0.1907  g_loss:3.8054
# epoch:525  d_loss:0.1674  g_loss:3.5983
# epoch:526  d_loss:0.1638  g_loss:2.6510
# epoch:527  d_loss:0.2071  g_loss:2.2949
# epoch:528  d_loss:0.1307  g_loss:2.5724
# epoch:529  d_loss:0.2117  g_loss:2.7480
# epoch:530  d_loss:0.2473  g_loss:2.9220
# epoch:531  d_loss:0.2251  g_loss:3.4181
# epoch:532  d_loss:0.2188  g_loss:3.2427
# epoch:533  d_loss:0.1493  g_loss:3.3730
# epoch:534  d_loss:0.1043  g_loss:2.5196
# epoch:535  d_loss:0.1640  g_loss:2.8026
# epoch:536  d_loss:0.2392  g_loss:2.7146
# epoch:537  d_loss:0.1422  g_loss:3.6365
# epoch:538  d_loss:0.2268  g_loss:3.7386
# epoch:539  d_loss:0.2475  g_loss:2.9732
# epoch:540  d_loss:0.2180  g_loss:2.4973
# epoch:541  d_loss:0.3665  g_loss:2.1854
# epoch:542  d_loss:0.1903  g_loss:2.6846
# epoch:543  d_loss:0.1958  g_loss:2.9929
# epoch:544  d_loss:0.3292  g_loss:2.5269
# epoch:545  d_loss:0.1940  g_loss:2.2625
# epoch:546  d_loss:0.2312  g_loss:2.2579
# epoch:547  d_loss:0.2820  g_loss:2.9444
# epoch:548  d_loss:0.2077  g_loss:2.4372
# epoch:549  d_loss:0.2893  g_loss:2.5470
# epoch:550  d_loss:0.2391  g_loss:2.6419
# epoch:551  d_loss:0.1690  g_loss:3.1892
# epoch:552  d_loss:0.3182  g_loss:3.8189
# epoch:553  d_loss:0.2614  g_loss:2.9453
# epoch:554  d_loss:0.2161  g_loss:2.8196
# epoch:555  d_loss:0.1499  g_loss:2.3667
# epoch:556  d_loss:0.2457  g_loss:2.5776
# epoch:557  d_loss:0.2233  g_loss:2.8380
# epoch:558  d_loss:0.1963  g_loss:3.4049
# epoch:559  d_loss:0.2455  g_loss:3.3351
# epoch:560  d_loss:0.2949  g_loss:2.9833
# epoch:561  d_loss:0.2055  g_loss:2.5356
# epoch:562  d_loss:0.2835  g_loss:2.2719
# epoch:563  d_loss:0.2316  g_loss:2.6635
# epoch:564  d_loss:0.2781  g_loss:2.1757
# epoch:565  d_loss:0.3165  g_loss:2.5354
# epoch:566  d_loss:0.2402  g_loss:2.9625
# epoch:567  d_loss:0.2881  g_loss:2.7684
# epoch:568  d_loss:0.2433  g_loss:2.5777
# epoch:569  d_loss:0.1752  g_loss:3.2385
# epoch:570  d_loss:0.1987  g_loss:2.6220
# epoch:571  d_loss:0.2721  g_loss:2.8415
# epoch:572  d_loss:0.1879  g_loss:2.4216
# epoch:573  d_loss:0.3319  g_loss:2.8418
# epoch:574  d_loss:0.1927  g_loss:3.7184
# epoch:575  d_loss:0.1266  g_loss:3.4174
# epoch:576  d_loss:0.2197  g_loss:4.1647
# epoch:577  d_loss:0.2266  g_loss:2.8708
# epoch:578  d_loss:0.2832  g_loss:2.8367
# epoch:579  d_loss:0.1146  g_loss:3.1551
# epoch:580  d_loss:0.1994  g_loss:3.1789
# epoch:581  d_loss:0.2327  g_loss:3.0345
# epoch:582  d_loss:0.1838  g_loss:3.6256
# epoch:583  d_loss:0.0853  g_loss:4.8420
# epoch:584  d_loss:0.2489  g_loss:4.0419
# epoch:585  d_loss:0.2378  g_loss:3.1060
# epoch:586  d_loss:0.2817  g_loss:2.6204
# epoch:587  d_loss:0.2292  g_loss:3.4327
# epoch:588  d_loss:0.2351  g_loss:3.4508
# epoch:589  d_loss:0.1930  g_loss:3.0965
# epoch:590  d_loss:0.2406  g_loss:2.1242
# epoch:591  d_loss:0.2723  g_loss:2.1222
# epoch:592  d_loss:0.1342  g_loss:3.0896
# epoch:593  d_loss:0.1822  g_loss:3.6940
# epoch:594  d_loss:0.1349  g_loss:4.2982
# epoch:595  d_loss:0.2596  g_loss:3.7354
# epoch:596  d_loss:0.2385  g_loss:2.8859
# epoch:597  d_loss:0.2081  g_loss:2.8889
# epoch:598  d_loss:0.1235  g_loss:3.1761
# epoch:599  d_loss:0.1960  g_loss:3.1241
# epoch:600  d_loss:0.1511  g_loss:3.8514
# epoch:601  d_loss:0.1465  g_loss:3.2874
# epoch:602  d_loss:0.2696  g_loss:2.9183
# epoch:603  d_loss:0.2140  g_loss:2.0684
# epoch:604  d_loss:0.3567  g_loss:2.0994
# epoch:605  d_loss:0.1895  g_loss:3.3969
# epoch:606  d_loss:0.1883  g_loss:4.1846
# epoch:607  d_loss:0.4034  g_loss:3.9853
# epoch:608  d_loss:0.3296  g_loss:2.9761
# epoch:609  d_loss:0.2316  g_loss:1.7880
# epoch:610  d_loss:0.2338  g_loss:2.2587
# epoch:611  d_loss:0.1317  g_loss:2.7481
# epoch:612  d_loss:0.1723  g_loss:3.2780
# epoch:613  d_loss:0.2825  g_loss:3.3937
# epoch:614  d_loss:0.2085  g_loss:4.2561
# epoch:615  d_loss:0.3137  g_loss:3.0385
# epoch:616  d_loss:0.2392  g_loss:2.5284
# epoch:617  d_loss:0.2176  g_loss:2.3793
# epoch:618  d_loss:0.2099  g_loss:2.6380
# epoch:619  d_loss:0.1725  g_loss:2.8959
# epoch:620  d_loss:0.2512  g_loss:3.5623
# epoch:621  d_loss:0.1350  g_loss:2.8767
# epoch:622  d_loss:0.1220  g_loss:3.6464
# epoch:623  d_loss:0.2136  g_loss:3.6599
# epoch:624  d_loss:0.3165  g_loss:3.0405
# epoch:625  d_loss:0.2473  g_loss:3.1802
# epoch:626  d_loss:0.1906  g_loss:2.4668
# epoch:627  d_loss:0.1054  g_loss:2.5622
# epoch:628  d_loss:0.1818  g_loss:3.1652
# epoch:629  d_loss:0.1752  g_loss:2.7399
# epoch:630  d_loss:0.1852  g_loss:2.4652
# epoch:631  d_loss:0.1678  g_loss:2.5005
# epoch:632  d_loss:0.2732  g_loss:1.9578
# epoch:633  d_loss:0.2519  g_loss:2.0656
# epoch:634  d_loss:0.3250  g_loss:2.4030
# epoch:635  d_loss:0.2493  g_loss:2.3307
# epoch:636  d_loss:0.4534  g_loss:1.6493
# epoch:637  d_loss:0.4437  g_loss:1.6525
# epoch:638  d_loss:0.2673  g_loss:2.6967
# epoch:639  d_loss:0.4109  g_loss:2.2456
# epoch:640  d_loss:0.5812  g_loss:1.5001
# epoch:641  d_loss:0.6328  g_loss:1.0059
# epoch:642  d_loss:0.3842  g_loss:1.7480
# epoch:643  d_loss:0.2218  g_loss:2.8870
# epoch:644  d_loss:0.4931  g_loss:2.8281
# epoch:645  d_loss:0.5657  g_loss:2.3958
# epoch:646  d_loss:0.3907  g_loss:1.6064
# epoch:647  d_loss:0.4783  g_loss:2.2318
# epoch:648  d_loss:0.3314  g_loss:2.2934
# epoch:649  d_loss:0.2114  g_loss:2.5068
# epoch:650  d_loss:0.4258  g_loss:2.3238
# epoch:651  d_loss:0.5192  g_loss:1.3766
# epoch:652  d_loss:0.4524  g_loss:1.5153
# epoch:653  d_loss:0.7472  g_loss:0.9120
# epoch:654  d_loss:0.7335  g_loss:0.8614
# epoch:655  d_loss:0.6813  g_loss:0.9080
# epoch:656  d_loss:0.4400  g_loss:0.7511
# epoch:657  d_loss:0.5922  g_loss:0.6608
# epoch:658  d_loss:0.4935  g_loss:0.7911
# epoch:659  d_loss:0.6762  g_loss:1.2661
# epoch:660  d_loss:0.4189  g_loss:1.9907
# epoch:661  d_loss:0.6060  g_loss:2.6638
# epoch:662  d_loss:0.7155  g_loss:1.9657
# epoch:663  d_loss:0.5515  g_loss:1.4095
# epoch:664  d_loss:0.6991  g_loss:1.5589
# epoch:665  d_loss:0.7025  g_loss:1.7763
# epoch:666  d_loss:0.3462  g_loss:2.1599
# epoch:667  d_loss:0.5482  g_loss:2.1817
# epoch:668  d_loss:0.4191  g_loss:2.1497
# epoch:669  d_loss:0.5186  g_loss:1.4498
# epoch:670  d_loss:0.7081  g_loss:0.9845
# epoch:671  d_loss:0.3336  g_loss:1.3975
# epoch:672  d_loss:0.4253  g_loss:1.6426
# epoch:673  d_loss:0.5482  g_loss:1.4758
# epoch:674  d_loss:0.5147  g_loss:1.5481
# epoch:675  d_loss:0.7037  g_loss:1.1352
# epoch:676  d_loss:0.8558  g_loss:0.8547
# epoch:677  d_loss:0.7133  g_loss:0.7990
# epoch:678  d_loss:0.6539  g_loss:0.8704
# epoch:679  d_loss:0.7089  g_loss:1.2602
# epoch:680  d_loss:0.9702  g_loss:1.0377
# epoch:681  d_loss:0.9168  g_loss:0.9607
# epoch:682  d_loss:0.7996  g_loss:0.9723
# epoch:683  d_loss:1.0241  g_loss:0.6789
# epoch:684  d_loss:0.8656  g_loss:0.7205
# epoch:685  d_loss:0.9502  g_loss:0.7780
# epoch:686  d_loss:0.8800  g_loss:1.0543
# epoch:687  d_loss:0.7128  g_loss:1.3048
# epoch:688  d_loss:0.7974  g_loss:1.0865
# epoch:689  d_loss:0.9510  g_loss:0.9077
# epoch:690  d_loss:0.8754  g_loss:0.6648
# epoch:691  d_loss:0.7944  g_loss:0.7562
# epoch:692  d_loss:0.5432  g_loss:0.9887
# epoch:693  d_loss:0.5544  g_loss:1.1421
# epoch:694  d_loss:0.7683  g_loss:1.0959
# epoch:695  d_loss:0.5731  g_loss:1.0202
# epoch:696  d_loss:0.5641  g_loss:1.1535
# epoch:697  d_loss:0.6011  g_loss:1.0276
# epoch:698  d_loss:0.3868  g_loss:1.3837
# epoch:699  d_loss:0.5049  g_loss:1.3803
# epoch:700  d_loss:0.4203  g_loss:1.4307
# epoch:701  d_loss:0.3861  g_loss:1.5163
# epoch:702  d_loss:0.4238  g_loss:1.1595
# epoch:703  d_loss:0.4667  g_loss:1.4019
# epoch:704  d_loss:0.3906  g_loss:1.4271
# epoch:705  d_loss:0.4314  g_loss:1.4046
# epoch:706  d_loss:0.3072  g_loss:1.5247
# epoch:707  d_loss:0.4790  g_loss:1.2765
# epoch:708  d_loss:0.4502  g_loss:1.3252
# epoch:709  d_loss:0.5280  g_loss:1.2532
# epoch:710  d_loss:0.6712  g_loss:1.2009
# epoch:711  d_loss:0.5017  g_loss:1.4550
# epoch:712  d_loss:0.6020  g_loss:1.3210
# epoch:713  d_loss:0.6104  g_loss:1.5011
# epoch:714  d_loss:0.4958  g_loss:1.5464
# epoch:715  d_loss:0.4710  g_loss:1.6861
# epoch:716  d_loss:0.3927  g_loss:1.8712
# epoch:717  d_loss:0.3337  g_loss:2.2520
# epoch:718  d_loss:0.4610  g_loss:2.3765
# epoch:719  d_loss:0.3121  g_loss:2.6481
# epoch:720  d_loss:0.6441  g_loss:2.1066
# epoch:721  d_loss:0.4988  g_loss:1.6784
# epoch:722  d_loss:0.4630  g_loss:1.6107
# epoch:723  d_loss:0.3375  g_loss:1.7537
# epoch:724  d_loss:0.3725  g_loss:2.2302
# epoch:725  d_loss:0.4071  g_loss:2.5202
# epoch:726  d_loss:0.3534  g_loss:2.2664
# epoch:727  d_loss:0.4680  g_loss:2.3053
# epoch:728  d_loss:0.2772  g_loss:2.6408
# epoch:729  d_loss:0.2534  g_loss:2.5186
# epoch:730  d_loss:0.3376  g_loss:2.6431
# epoch:731  d_loss:0.3067  g_loss:2.4489
# epoch:732  d_loss:0.4763  g_loss:2.5211
# epoch:733  d_loss:0.3978  g_loss:2.5091
# epoch:734  d_loss:0.2956  g_loss:2.8167
# epoch:735  d_loss:0.3507  g_loss:3.0834
# epoch:736  d_loss:0.3708  g_loss:3.3180
# epoch:737  d_loss:0.4535  g_loss:2.2076
# epoch:738  d_loss:0.3743  g_loss:2.0731
# epoch:739  d_loss:0.4165  g_loss:2.1689
# epoch:740  d_loss:0.6241  g_loss:1.7393
# epoch:741  d_loss:0.7200  g_loss:1.8537
# epoch:742  d_loss:0.6014  g_loss:2.0888
# epoch:743  d_loss:0.5194  g_loss:2.1993
# epoch:744  d_loss:0.7930  g_loss:1.6049
# epoch:745  d_loss:0.5599  g_loss:1.7708
# epoch:746  d_loss:0.7370  g_loss:1.5421
# epoch:747  d_loss:0.7268  g_loss:1.5813
# epoch:748  d_loss:0.3849  g_loss:2.3916
# epoch:749  d_loss:0.5950  g_loss:1.8689
# epoch:750  d_loss:0.4659  g_loss:1.8842
# epoch:751  d_loss:0.4264  g_loss:1.6562
# epoch:752  d_loss:0.3684  g_loss:1.8561
# epoch:753  d_loss:0.3064  g_loss:2.0319
# epoch:754  d_loss:0.3763  g_loss:1.7854
# epoch:755  d_loss:0.2508  g_loss:2.3245
# epoch:756  d_loss:0.2975  g_loss:2.4055
# epoch:757  d_loss:0.3400  g_loss:2.4835
# epoch:758  d_loss:0.2768  g_loss:2.3776
# epoch:759  d_loss:0.2599  g_loss:2.3509
# epoch:760  d_loss:0.2556  g_loss:2.3618
# epoch:761  d_loss:0.2135  g_loss:2.8364
# epoch:762  d_loss:0.2215  g_loss:2.6092
# epoch:763  d_loss:0.2016  g_loss:2.6108
# epoch:764  d_loss:0.2259  g_loss:2.4769
# epoch:765  d_loss:0.2612  g_loss:2.2139
# epoch:766  d_loss:0.2665  g_loss:2.6222
# epoch:767  d_loss:0.2920  g_loss:2.4124
# epoch:768  d_loss:0.2145  g_loss:3.0454
# epoch:769  d_loss:0.3202  g_loss:2.6057
# epoch:770  d_loss:0.5181  g_loss:2.2913
# epoch:771  d_loss:0.4552  g_loss:2.1675
# epoch:772  d_loss:0.3076  g_loss:2.0543
# epoch:773  d_loss:0.5351  g_loss:1.6339
# epoch:774  d_loss:0.6239  g_loss:1.8227
# epoch:775  d_loss:0.5158  g_loss:2.1843
# epoch:776  d_loss:0.5061  g_loss:1.8513
# epoch:777  d_loss:0.6365  g_loss:1.6930
# epoch:778  d_loss:0.6435  g_loss:1.2310
# epoch:779  d_loss:0.6643  g_loss:1.2405
# epoch:780  d_loss:0.6197  g_loss:1.6920
# epoch:781  d_loss:0.5257  g_loss:1.7808
# epoch:782  d_loss:0.6543  g_loss:1.6855
# epoch:783  d_loss:0.5288  g_loss:1.7090
# epoch:784  d_loss:0.5311  g_loss:1.4237
# epoch:785  d_loss:0.3035  g_loss:1.8422
# epoch:786  d_loss:0.3454  g_loss:2.2362
# epoch:787  d_loss:0.2348  g_loss:2.6534
# epoch:788  d_loss:0.3235  g_loss:3.3543
# epoch:789  d_loss:0.1660  g_loss:3.0534
# epoch:790  d_loss:0.2681  g_loss:2.6127
# epoch:791  d_loss:0.1835  g_loss:2.3388
# epoch:792  d_loss:0.2070  g_loss:2.3255
# epoch:793  d_loss:0.2137  g_loss:2.1595
# epoch:794  d_loss:0.1868  g_loss:2.8125
# epoch:795  d_loss:0.2142  g_loss:2.8824
# epoch:796  d_loss:0.2227  g_loss:3.4182
# epoch:797  d_loss:0.1458  g_loss:3.0750
# epoch:798  d_loss:0.2557  g_loss:3.2145
# epoch:799  d_loss:0.1958  g_loss:3.1253
# epoch:800  d_loss:0.2128  g_loss:2.5625
# epoch:801  d_loss:0.3262  g_loss:1.9137
# epoch:802  d_loss:0.2783  g_loss:2.0033
# epoch:803  d_loss:0.5620  g_loss:2.0216
# epoch:804  d_loss:0.3151  g_loss:3.2218
# epoch:805  d_loss:0.5732  g_loss:2.4010
# epoch:806  d_loss:0.6034  g_loss:2.0213
# epoch:807  d_loss:0.3903  g_loss:1.7024
# epoch:808  d_loss:0.3823  g_loss:1.6931
# epoch:809  d_loss:0.4171  g_loss:2.0527
# epoch:810  d_loss:0.3013  g_loss:1.8144
# epoch:811  d_loss:0.4142  g_loss:1.7837
# epoch:812  d_loss:0.5038  g_loss:2.2988
# epoch:813  d_loss:0.6483  g_loss:1.7265
# epoch:814  d_loss:0.5301  g_loss:1.2316
# epoch:815  d_loss:0.7371  g_loss:1.2390
# epoch:816  d_loss:0.4783  g_loss:1.8102
# epoch:817  d_loss:0.4102  g_loss:2.3581
# epoch:818  d_loss:0.4066  g_loss:2.3626
# epoch:819  d_loss:0.5722  g_loss:1.6094
# epoch:820  d_loss:0.3536  g_loss:1.7563
# epoch:821  d_loss:0.3061  g_loss:1.9063
# epoch:822  d_loss:0.3495  g_loss:1.7732
# epoch:823  d_loss:0.3888  g_loss:2.7830
# epoch:824  d_loss:0.4097  g_loss:3.0818
# epoch:825  d_loss:0.3385  g_loss:3.2532
# epoch:826  d_loss:0.6208  g_loss:2.3330
# epoch:827  d_loss:0.3760  g_loss:2.8078
# epoch:828  d_loss:0.2777  g_loss:2.6428
# epoch:829  d_loss:0.3320  g_loss:3.1958
# epoch:830  d_loss:0.3922  g_loss:2.1457
# epoch:831  d_loss:0.4647  g_loss:1.4565
# epoch:832  d_loss:0.5383  g_loss:1.5758
# epoch:833  d_loss:0.3605  g_loss:1.7122
# epoch:834  d_loss:0.4452  g_loss:2.1673
# epoch:835  d_loss:0.3422  g_loss:2.4429
# epoch:836  d_loss:0.5426  g_loss:2.4887
# epoch:837  d_loss:0.4476  g_loss:2.1307
# epoch:838  d_loss:0.4141  g_loss:1.6278
# epoch:839  d_loss:0.5898  g_loss:1.5874
# epoch:840  d_loss:0.4364  g_loss:1.5067
# epoch:841  d_loss:0.3937  g_loss:1.9003
# epoch:842  d_loss:0.5856  g_loss:1.5510
# epoch:843  d_loss:0.4569  g_loss:2.2513
# epoch:844  d_loss:0.4385  g_loss:1.7997
# epoch:845  d_loss:0.3337  g_loss:2.0175
# epoch:846  d_loss:0.5012  g_loss:2.2151
# epoch:847  d_loss:0.5111  g_loss:2.1616
# epoch:848  d_loss:0.3446  g_loss:1.9880
# epoch:849  d_loss:0.3855  g_loss:2.0345
# epoch:850  d_loss:0.2773  g_loss:2.2568
# epoch:851  d_loss:0.3256  g_loss:2.2886
# epoch:852  d_loss:0.3667  g_loss:2.3087
# epoch:853  d_loss:0.3065  g_loss:2.0788
# epoch:854  d_loss:0.2747  g_loss:2.4574
# epoch:855  d_loss:0.2586  g_loss:2.0418
# epoch:856  d_loss:0.2309  g_loss:2.3217
# epoch:857  d_loss:0.2330  g_loss:2.2826
# epoch:858  d_loss:0.1686  g_loss:2.6954
# epoch:859  d_loss:0.2175  g_loss:2.5483
# epoch:860  d_loss:0.3777  g_loss:2.0103
# epoch:861  d_loss:0.1708  g_loss:2.3702
# epoch:862  d_loss:0.3436  g_loss:1.9536
# epoch:863  d_loss:0.2978  g_loss:2.4725
# epoch:864  d_loss:0.3708  g_loss:2.4422
# epoch:865  d_loss:0.2552  g_loss:2.4506
# epoch:866  d_loss:0.3712  g_loss:2.6741
# epoch:867  d_loss:0.3487  g_loss:1.9408
# epoch:868  d_loss:0.3889  g_loss:1.9709
# epoch:869  d_loss:0.3810  g_loss:2.4208
# epoch:870  d_loss:0.4251  g_loss:2.4633
# epoch:871  d_loss:0.6420  g_loss:1.6840
# epoch:872  d_loss:0.4170  g_loss:2.1560
# epoch:873  d_loss:0.4778  g_loss:1.9092
# epoch:874  d_loss:0.3182  g_loss:2.3544
# epoch:875  d_loss:0.6386  g_loss:1.8652
# epoch:876  d_loss:0.5772  g_loss:1.6530
# epoch:877  d_loss:0.4982  g_loss:1.6638
# epoch:878  d_loss:0.4832  g_loss:1.6893
# epoch:879  d_loss:0.3749  g_loss:1.9758
# epoch:880  d_loss:0.4634  g_loss:1.9030
# epoch:881  d_loss:0.3361  g_loss:2.0964
# epoch:882  d_loss:0.4149  g_loss:2.0026
# epoch:883  d_loss:0.3531  g_loss:2.2160
# epoch:884  d_loss:0.3458  g_loss:2.1037
# epoch:885  d_loss:0.2570  g_loss:2.2298
# epoch:886  d_loss:0.3276  g_loss:2.3171
# epoch:887  d_loss:0.2882  g_loss:2.2971
# epoch:888  d_loss:0.2462  g_loss:2.2298
# epoch:889  d_loss:0.2679  g_loss:2.4889
# epoch:890  d_loss:0.3377  g_loss:2.2975
# epoch:891  d_loss:0.2320  g_loss:2.4837
# epoch:892  d_loss:0.3254  g_loss:2.3783
# epoch:893  d_loss:0.2732  g_loss:2.6010
# epoch:894  d_loss:0.2157  g_loss:2.8971
# epoch:895  d_loss:0.3277  g_loss:2.4654
# epoch:896  d_loss:0.2577  g_loss:2.0887
# epoch:897  d_loss:0.2586  g_loss:2.1741
# epoch:898  d_loss:0.2039  g_loss:2.7682
# epoch:899  d_loss:0.2918  g_loss:2.5326
# epoch:900  d_loss:0.2846  g_loss:2.4887
# epoch:901  d_loss:0.3768  g_loss:2.5529
# epoch:902  d_loss:0.2972  g_loss:2.7789
# epoch:903  d_loss:0.4046  g_loss:2.2003
# epoch:904  d_loss:0.4004  g_loss:1.8717
# epoch:905  d_loss:0.4058  g_loss:2.3303
# epoch:906  d_loss:0.4174  g_loss:2.0103
# epoch:907  d_loss:0.4624  g_loss:2.7041
# epoch:908  d_loss:0.5301  g_loss:2.6985
# epoch:909  d_loss:0.5520  g_loss:2.2536
# epoch:910  d_loss:0.4091  g_loss:2.5781
# epoch:911  d_loss:0.5097  g_loss:2.1870
# epoch:912  d_loss:0.4251  g_loss:2.0270
# epoch:913  d_loss:0.6222  g_loss:1.9334
# epoch:914  d_loss:0.3728  g_loss:2.4420
# epoch:915  d_loss:0.3747  g_loss:2.4345
# epoch:916  d_loss:0.4658  g_loss:2.6347
# epoch:917  d_loss:0.4962  g_loss:2.2708
# epoch:918  d_loss:0.5057  g_loss:2.3873
# epoch:919  d_loss:0.4557  g_loss:1.9345
# epoch:920  d_loss:0.4176  g_loss:2.1887
# epoch:921  d_loss:0.3234  g_loss:2.2090
# epoch:922  d_loss:0.2997  g_loss:2.1180
# epoch:923  d_loss:0.2808  g_loss:2.6088
# epoch:924  d_loss:0.4199  g_loss:2.4545
# epoch:925  d_loss:0.2943  g_loss:2.4069
# epoch:926  d_loss:0.3073  g_loss:2.2896
# epoch:927  d_loss:0.2990  g_loss:2.1500
# epoch:928  d_loss:0.3488  g_loss:2.1809
# epoch:929  d_loss:0.2881  g_loss:2.1729
# epoch:930  d_loss:0.3086  g_loss:1.7139
# epoch:931  d_loss:0.2878  g_loss:2.8966
# epoch:932  d_loss:0.2425  g_loss:2.8432
# epoch:933  d_loss:0.2515  g_loss:2.5801
# epoch:934  d_loss:0.3454  g_loss:2.5487
# epoch:935  d_loss:0.3373  g_loss:1.7558
# epoch:936  d_loss:0.3932  g_loss:2.0110
# epoch:937  d_loss:0.4725  g_loss:2.2421
# epoch:938  d_loss:0.3920  g_loss:2.1542
# epoch:939  d_loss:0.3388  g_loss:2.3050
# epoch:940  d_loss:0.5157  g_loss:1.9522
# epoch:941  d_loss:0.4566  g_loss:2.2705
# epoch:942  d_loss:0.5755  g_loss:1.6133
# epoch:943  d_loss:0.3004  g_loss:2.0536
# epoch:944  d_loss:0.3921  g_loss:1.8821
# epoch:945  d_loss:0.3572  g_loss:2.0365
# epoch:946  d_loss:0.5138  g_loss:2.1943
# epoch:947  d_loss:0.3814  g_loss:1.9945
# epoch:948  d_loss:0.4574  g_loss:2.3000
# epoch:949  d_loss:0.3416  g_loss:2.1952
# epoch:950  d_loss:0.4537  g_loss:2.0072
# epoch:951  d_loss:0.3320  g_loss:2.1129
# epoch:952  d_loss:0.3273  g_loss:2.1148
# epoch:953  d_loss:0.2550  g_loss:2.8664
# epoch:954  d_loss:0.2689  g_loss:2.9200
# epoch:955  d_loss:0.3480  g_loss:2.7476
# epoch:956  d_loss:0.1659  g_loss:2.8594
# epoch:957  d_loss:0.2341  g_loss:2.8393
# epoch:958  d_loss:0.2591  g_loss:2.1831
# epoch:959  d_loss:0.2973  g_loss:1.9541
# epoch:960  d_loss:0.4083  g_loss:2.0258
# epoch:961  d_loss:0.3064  g_loss:2.7737
# epoch:962  d_loss:0.2829  g_loss:3.1162
# epoch:963  d_loss:0.3052  g_loss:3.0595
# epoch:964  d_loss:0.2549  g_loss:2.9189
# epoch:965  d_loss:0.4114  g_loss:2.4301
# epoch:966  d_loss:0.3286  g_loss:2.7832
# epoch:967  d_loss:0.4238  g_loss:2.2672
# epoch:968  d_loss:0.3203  g_loss:2.5318
# epoch:969  d_loss:0.2910  g_loss:2.6927
# epoch:970  d_loss:0.4255  g_loss:2.1371
# epoch:971  d_loss:0.3745  g_loss:2.2855
# epoch:972  d_loss:0.3192  g_loss:2.2220
# epoch:973  d_loss:0.4330  g_loss:1.9718
# epoch:974  d_loss:0.4829  g_loss:2.2962
# epoch:975  d_loss:0.3202  g_loss:2.6538
# epoch:976  d_loss:0.5921  g_loss:2.2222
# epoch:977  d_loss:0.3099  g_loss:2.4331
# epoch:978  d_loss:0.2995  g_loss:2.1536
# epoch:979  d_loss:0.2096  g_loss:2.3414
# epoch:980  d_loss:0.3138  g_loss:1.9575
# epoch:981  d_loss:0.2941  g_loss:1.7354
# epoch:982  d_loss:0.3139  g_loss:2.0555
# epoch:983  d_loss:0.3058  g_loss:2.0473
# epoch:984  d_loss:0.3518  g_loss:2.4005
# epoch:985  d_loss:0.2878  g_loss:2.4734
# epoch:986  d_loss:0.2341  g_loss:2.5560
# epoch:987  d_loss:0.2543  g_loss:2.5178
# epoch:988  d_loss:0.4110  g_loss:1.8229
# epoch:989  d_loss:0.3290  g_loss:2.2861
# epoch:990  d_loss:0.2119  g_loss:2.6300
# epoch:991  d_loss:0.4018  g_loss:2.1131
# epoch:992  d_loss:0.3994  g_loss:1.7857
# epoch:993  d_loss:0.4088  g_loss:2.2121
# epoch:994  d_loss:0.4966  g_loss:2.3974
# epoch:995  d_loss:0.4925  g_loss:2.1978
# epoch:996  d_loss:0.5843  g_loss:1.8091
# epoch:997  d_loss:0.4176  g_loss:1.6179
# epoch:998  d_loss:0.5943  g_loss:1.9252
# epoch:999  d_loss:0.4544  g_loss:1.7208
# epoch:1000  d_loss:0.2937  g_loss:2.3696
# epoch:1001  d_loss:0.3479  g_loss:2.6794
# epoch:1002  d_loss:0.4645  g_loss:1.9877
# epoch:1003  d_loss:0.4962  g_loss:1.7905
# epoch:1004  d_loss:0.6314  g_loss:1.6221
# epoch:1005  d_loss:0.5205  g_loss:1.8434
# epoch:1006  d_loss:0.3474  g_loss:1.9454
# epoch:1007  d_loss:0.3032  g_loss:2.0272
# epoch:1008  d_loss:0.4511  g_loss:1.8541
# epoch:1009  d_loss:0.3083  g_loss:2.2984
# epoch:1010  d_loss:0.4517  g_loss:2.1969
# epoch:1011  d_loss:0.4115  g_loss:1.9126
# epoch:1012  d_loss:0.5066  g_loss:1.5443
# epoch:1013  d_loss:0.3455  g_loss:2.2493
# epoch:1014  d_loss:0.4349  g_loss:2.1756
# epoch:1015  d_loss:0.6369  g_loss:1.7020
# epoch:1016  d_loss:0.4807  g_loss:1.9776
# epoch:1017  d_loss:0.4484  g_loss:2.3095
# epoch:1018  d_loss:0.4804  g_loss:2.0765
# epoch:1019  d_loss:0.4388  g_loss:1.5489
# epoch:1020  d_loss:0.5193  g_loss:1.8322
# epoch:1021  d_loss:0.3302  g_loss:2.2080
# epoch:1022  d_loss:0.4832  g_loss:2.4689
# epoch:1023  d_loss:0.3984  g_loss:2.1418
# epoch:1024  d_loss:0.5249  g_loss:1.8135
# epoch:1025  d_loss:0.5174  g_loss:1.6346
# epoch:1026  d_loss:0.2804  g_loss:1.4506
# epoch:1027  d_loss:0.3446  g_loss:1.8333
# epoch:1028  d_loss:0.4187  g_loss:2.0487
# epoch:1029  d_loss:0.2527  g_loss:2.5338
# epoch:1030  d_loss:0.2305  g_loss:2.4243
# epoch:1031  d_loss:0.3091  g_loss:2.0292
# epoch:1032  d_loss:0.2545  g_loss:2.3526
# epoch:1033  d_loss:0.2737  g_loss:2.6479
# epoch:1034  d_loss:0.2767  g_loss:1.9813
# epoch:1035  d_loss:0.4512  g_loss:1.6443
# epoch:1036  d_loss:0.3438  g_loss:1.9695
# epoch:1037  d_loss:0.3006  g_loss:2.2161
# epoch:1038  d_loss:0.3803  g_loss:1.8045
# epoch:1039  d_loss:0.3216  g_loss:2.4305
# epoch:1040  d_loss:0.4539  g_loss:2.0019
# epoch:1041  d_loss:0.2703  g_loss:2.0491
# epoch:1042  d_loss:0.5985  g_loss:1.7357
# epoch:1043  d_loss:0.3353  g_loss:2.2604
# epoch:1044  d_loss:0.3086  g_loss:2.1137
# epoch:1045  d_loss:0.3846  g_loss:2.3318
# epoch:1046  d_loss:0.4985  g_loss:1.8262
# epoch:1047  d_loss:0.3016  g_loss:2.2204
# epoch:1048  d_loss:0.3369  g_loss:2.4348
# epoch:1049  d_loss:0.3146  g_loss:2.6191
# epoch:1050  d_loss:0.4277  g_loss:2.6793
# epoch:1051  d_loss:0.5156  g_loss:2.0643
# epoch:1052  d_loss:0.3889  g_loss:2.1508
# epoch:1053  d_loss:0.4600  g_loss:1.9344
# epoch:1054  d_loss:0.2506  g_loss:3.0104
# epoch:1055  d_loss:0.3693  g_loss:2.8165
# epoch:1056  d_loss:0.3856  g_loss:2.4311
# epoch:1057  d_loss:0.3458  g_loss:2.2856
# epoch:1058  d_loss:0.4484  g_loss:2.2204
# epoch:1059  d_loss:0.4779  g_loss:2.0722
# epoch:1060  d_loss:0.3584  g_loss:2.1509
# epoch:1061  d_loss:0.3601  g_loss:2.0768
# epoch:1062  d_loss:0.2886  g_loss:1.9270
# epoch:1063  d_loss:0.4852  g_loss:1.6364
# epoch:1064  d_loss:0.5197  g_loss:1.7114
# epoch:1065  d_loss:0.3791  g_loss:2.0412
# epoch:1066  d_loss:0.3541  g_loss:2.3443
# epoch:1067  d_loss:0.3423  g_loss:2.5456
# epoch:1068  d_loss:0.2779  g_loss:2.4210
# epoch:1069  d_loss:0.3068  g_loss:2.5538
# epoch:1070  d_loss:0.3364  g_loss:2.6264
# epoch:1071  d_loss:0.3020  g_loss:1.7984
# epoch:1072  d_loss:0.4105  g_loss:2.6767
# epoch:1073  d_loss:0.3408  g_loss:2.2745
# epoch:1074  d_loss:0.3516  g_loss:2.3951
# epoch:1075  d_loss:0.3198  g_loss:2.0562
# epoch:1076  d_loss:0.2428  g_loss:2.4169
# epoch:1077  d_loss:0.2332  g_loss:1.9019
# epoch:1078  d_loss:0.1776  g_loss:2.5114
# epoch:1079  d_loss:0.2234  g_loss:3.2284
# epoch:1080  d_loss:0.3579  g_loss:2.5143
# epoch:1081  d_loss:0.2744  g_loss:1.9864
# epoch:1082  d_loss:0.3455  g_loss:2.1656
# epoch:1083  d_loss:0.2806  g_loss:2.5433
# epoch:1084  d_loss:0.3696  g_loss:2.3642
# epoch:1085  d_loss:0.3164  g_loss:2.6163
# epoch:1086  d_loss:0.4299  g_loss:2.4728
# epoch:1087  d_loss:0.3754  g_loss:2.0752
# epoch:1088  d_loss:0.4806  g_loss:1.8046
# epoch:1089  d_loss:0.2644  g_loss:2.0880
# epoch:1090  d_loss:0.4499  g_loss:2.2110
# epoch:1091  d_loss:0.3623  g_loss:2.2890
# epoch:1092  d_loss:0.3963  g_loss:2.0780
# epoch:1093  d_loss:0.3010  g_loss:2.5942
# epoch:1094  d_loss:0.3882  g_loss:2.4616
# epoch:1095  d_loss:0.4739  g_loss:2.1483
# epoch:1096  d_loss:0.4716  g_loss:1.7639
# epoch:1097  d_loss:0.3387  g_loss:2.0697
# epoch:1098  d_loss:0.3966  g_loss:2.0412
# epoch:1099  d_loss:0.6326  g_loss:2.1646
# epoch:1100  d_loss:0.4532  g_loss:2.2996
# epoch:1101  d_loss:0.4140  g_loss:2.4307
# epoch:1102  d_loss:0.4313  g_loss:2.2629
# epoch:1103  d_loss:0.4592  g_loss:1.8743
# epoch:1104  d_loss:0.5061  g_loss:1.7414
# epoch:1105  d_loss:0.4914  g_loss:1.5980
# epoch:1106  d_loss:0.3246  g_loss:1.8777
# epoch:1107  d_loss:0.4252  g_loss:1.6900
# epoch:1108  d_loss:0.4831  g_loss:2.4134
# epoch:1109  d_loss:0.3483  g_loss:1.9445
# epoch:1110  d_loss:0.5642  g_loss:1.8018
# epoch:1111  d_loss:0.4642  g_loss:1.3978
# epoch:1112  d_loss:0.4393  g_loss:1.6156
# epoch:1113  d_loss:0.4058  g_loss:1.7838
# epoch:1114  d_loss:0.2767  g_loss:2.3126
# epoch:1115  d_loss:0.4802  g_loss:2.3100
# epoch:1116  d_loss:0.5735  g_loss:2.0060
# epoch:1117  d_loss:0.3504  g_loss:2.2766
# epoch:1118  d_loss:0.4125  g_loss:1.6941
# epoch:1119  d_loss:0.3410  g_loss:1.7447
# epoch:1120  d_loss:0.4239  g_loss:1.6578
# epoch:1121  d_loss:0.5643  g_loss:1.9166
# epoch:1122  d_loss:0.3080  g_loss:2.3841
# epoch:1123  d_loss:0.4087  g_loss:2.4203
# epoch:1124  d_loss:0.4571  g_loss:2.0712
# epoch:1125  d_loss:0.3411  g_loss:1.6572
# epoch:1126  d_loss:0.3651  g_loss:1.7109
# epoch:1127  d_loss:0.4406  g_loss:2.1875
# epoch:1128  d_loss:0.3234  g_loss:2.1715
# epoch:1129  d_loss:0.3423  g_loss:1.9836
# epoch:1130  d_loss:0.3514  g_loss:2.2560
# epoch:1131  d_loss:0.4745  g_loss:2.2666
# epoch:1132  d_loss:0.4404  g_loss:2.1450
# epoch:1133  d_loss:0.3064  g_loss:2.2805
# epoch:1134  d_loss:0.3765  g_loss:1.9302
# epoch:1135  d_loss:0.5504  g_loss:1.3933
# epoch:1136  d_loss:0.3879  g_loss:1.7792
# epoch:1137  d_loss:0.3409  g_loss:2.2663
# epoch:1138  d_loss:0.3516  g_loss:2.3952
# epoch:1139  d_loss:0.4305  g_loss:1.5632
# epoch:1140  d_loss:0.4618  g_loss:1.8554
# epoch:1141  d_loss:0.4721  g_loss:1.8740
# epoch:1142  d_loss:0.2595  g_loss:2.4517
# epoch:1143  d_loss:0.3901  g_loss:1.9551
# epoch:1144  d_loss:0.3612  g_loss:2.4935
# epoch:1145  d_loss:0.3812  g_loss:1.7555
# epoch:1146  d_loss:0.4078  g_loss:1.6727
# epoch:1147  d_loss:0.4715  g_loss:1.6548
# epoch:1148  d_loss:0.4556  g_loss:1.8004
# epoch:1149  d_loss:0.3372  g_loss:2.3850
# epoch:1150  d_loss:0.3995  g_loss:2.6209
# epoch:1151  d_loss:0.2354  g_loss:2.4541
# epoch:1152  d_loss:0.3458  g_loss:2.4972
# epoch:1153  d_loss:0.3977  g_loss:2.1806
# epoch:1154  d_loss:0.4453  g_loss:1.5265
# epoch:1155  d_loss:0.3296  g_loss:1.9791
# epoch:1156  d_loss:0.3294  g_loss:2.2656
# epoch:1157  d_loss:0.2857  g_loss:2.4452
# epoch:1158  d_loss:0.3271  g_loss:2.2056
# epoch:1159  d_loss:0.2898  g_loss:2.3157
# epoch:1160  d_loss:0.2722  g_loss:2.4553
# epoch:1161  d_loss:0.3205  g_loss:2.3147
# epoch:1162  d_loss:0.5843  g_loss:2.4329
# epoch:1163  d_loss:0.3877  g_loss:1.7325
# epoch:1164  d_loss:0.4034  g_loss:1.8241
# epoch:1165  d_loss:0.3789  g_loss:1.8252
# epoch:1166  d_loss:0.2993  g_loss:2.3252
# epoch:1167  d_loss:0.4094  g_loss:2.3080
# epoch:1168  d_loss:0.3584  g_loss:2.1488
# epoch:1169  d_loss:0.4747  g_loss:2.1275
# epoch:1170  d_loss:0.4473  g_loss:2.2733
# epoch:1171  d_loss:0.3679  g_loss:2.2337
# epoch:1172  d_loss:0.4046  g_loss:2.0130
# epoch:1173  d_loss:0.3733  g_loss:1.8745
# epoch:1174  d_loss:0.3577  g_loss:2.2925
# epoch:1175  d_loss:0.3915  g_loss:2.6593
# epoch:1176  d_loss:0.4639  g_loss:2.5211
# epoch:1177  d_loss:0.5812  g_loss:2.6511
# epoch:1178  d_loss:0.4078  g_loss:2.3424
# epoch:1179  d_loss:0.4264  g_loss:2.4225
# epoch:1180  d_loss:0.2870  g_loss:2.8570
# epoch:1181  d_loss:0.3953  g_loss:2.1932
# epoch:1182  d_loss:0.3155  g_loss:2.3454
# epoch:1183  d_loss:0.2970  g_loss:2.2896
# epoch:1184  d_loss:0.3862  g_loss:2.0916
# epoch:1185  d_loss:0.2811  g_loss:2.6032
# epoch:1186  d_loss:0.3563  g_loss:3.4209
# epoch:1187  d_loss:0.3068  g_loss:2.6066
# epoch:1188  d_loss:0.2311  g_loss:2.9722
# epoch:1189  d_loss:0.4763  g_loss:2.1965
# epoch:1190  d_loss:0.4172  g_loss:2.7300
# epoch:1191  d_loss:0.2840  g_loss:2.8440
# epoch:1192  d_loss:0.2249  g_loss:2.3626
# epoch:1193  d_loss:0.5095  g_loss:2.2104
# epoch:1194  d_loss:0.3927  g_loss:2.5601
# epoch:1195  d_loss:0.4447  g_loss:2.5008
# epoch:1196  d_loss:0.2683  g_loss:2.4648
# epoch:1197  d_loss:0.4512  g_loss:2.1524
# epoch:1198  d_loss:0.3900  g_loss:2.1206
# epoch:1199  d_loss:0.3382  g_loss:2.9972
# epoch:1200  d_loss:0.3916  g_loss:2.1650
# epoch:1201  d_loss:0.4803  g_loss:2.1027
# epoch:1202  d_loss:0.2948  g_loss:2.6554
# epoch:1203  d_loss:0.4601  g_loss:2.2628
# epoch:1204  d_loss:0.4317  g_loss:1.9505
# epoch:1205  d_loss:0.3987  g_loss:2.6949
# epoch:1206  d_loss:0.4020  g_loss:2.3121
# epoch:1207  d_loss:0.5482  g_loss:2.0059
# epoch:1208  d_loss:0.5330  g_loss:1.6150
# epoch:1209  d_loss:0.3282  g_loss:1.9899
# epoch:1210  d_loss:0.4746  g_loss:1.4988
# epoch:1211  d_loss:0.4719  g_loss:1.6791
# epoch:1212  d_loss:0.5150  g_loss:1.4489
# epoch:1213  d_loss:0.4641  g_loss:1.5655
# epoch:1214  d_loss:0.5344  g_loss:1.6584
# epoch:1215  d_loss:0.4301  g_loss:2.2598
# epoch:1216  d_loss:0.5519  g_loss:1.9148
# epoch:1217  d_loss:0.5838  g_loss:1.7068
# epoch:1218  d_loss:0.4776  g_loss:1.4002
# epoch:1219  d_loss:0.3624  g_loss:1.7675
# epoch:1220  d_loss:0.2798  g_loss:2.0298
# epoch:1221  d_loss:0.3554  g_loss:2.1683
# epoch:1222  d_loss:0.4697  g_loss:1.8684
# epoch:1223  d_loss:0.3721  g_loss:1.9837
# epoch:1224  d_loss:0.4237  g_loss:2.2087
# epoch:1225  d_loss:0.3320  g_loss:2.7850
# epoch:1226  d_loss:0.3739  g_loss:2.3628
# epoch:1227  d_loss:0.2534  g_loss:2.2801
# epoch:1228  d_loss:0.4145  g_loss:2.2333
# epoch:1229  d_loss:0.3445  g_loss:1.9762
# epoch:1230  d_loss:0.4393  g_loss:2.0865
# epoch:1231  d_loss:0.3667  g_loss:2.8862
# epoch:1232  d_loss:0.2691  g_loss:2.6927
# epoch:1233  d_loss:0.3557  g_loss:2.5157
# epoch:1234  d_loss:0.3076  g_loss:2.4550
# epoch:1235  d_loss:0.3192  g_loss:2.3689
# epoch:1236  d_loss:0.2876  g_loss:2.3996
# epoch:1237  d_loss:0.3399  g_loss:2.0607
# epoch:1238  d_loss:0.4894  g_loss:2.3086
# epoch:1239  d_loss:0.2769  g_loss:2.0232
# epoch:1240  d_loss:0.3997  g_loss:1.8990
# epoch:1241  d_loss:0.3352  g_loss:2.9772
# epoch:1242  d_loss:0.3351  g_loss:2.7456
# epoch:1243  d_loss:0.4773  g_loss:2.2978
# epoch:1244  d_loss:0.4195  g_loss:2.2744
# epoch:1245  d_loss:0.3642  g_loss:2.5200
# epoch:1246  d_loss:0.4566  g_loss:2.4213
# epoch:1247  d_loss:0.3636  g_loss:2.4518
# epoch:1248  d_loss:0.4179  g_loss:2.5350
# epoch:1249  d_loss:0.3536  g_loss:1.7652
# epoch:1250  d_loss:0.3206  g_loss:2.1941
# epoch:1251  d_loss:0.4219  g_loss:2.3193
# epoch:1252  d_loss:0.3633  g_loss:2.4976
# epoch:1253  d_loss:0.2955  g_loss:3.3319
# epoch:1254  d_loss:0.4579  g_loss:2.8141
# epoch:1255  d_loss:0.3867  g_loss:2.5530
# epoch:1256  d_loss:0.3260  g_loss:2.4696
# epoch:1257  d_loss:0.5547  g_loss:1.5547
# epoch:1258  d_loss:0.3489  g_loss:2.1040
# epoch:1259  d_loss:0.2269  g_loss:3.1022
# epoch:1260  d_loss:0.4580  g_loss:3.2029
# epoch:1261  d_loss:0.3001  g_loss:2.4626
# epoch:1262  d_loss:0.3794  g_loss:2.5808
# epoch:1263  d_loss:0.2726  g_loss:1.7414
# epoch:1264  d_loss:0.4294  g_loss:1.9498
# epoch:1265  d_loss:0.3170  g_loss:2.7767
# epoch:1266  d_loss:0.3386  g_loss:2.9630
# epoch:1267  d_loss:0.2247  g_loss:2.8254
# epoch:1268  d_loss:0.5101  g_loss:2.5009
# epoch:1269  d_loss:0.2533  g_loss:2.3623
# epoch:1270  d_loss:0.6102  g_loss:2.3260
# epoch:1271  d_loss:0.5678  g_loss:2.4028
# epoch:1272  d_loss:0.5035  g_loss:3.4463
# epoch:1273  d_loss:0.5259  g_loss:3.0266
# epoch:1274  d_loss:0.4796  g_loss:2.8081
# epoch:1275  d_loss:0.3236  g_loss:2.6169
# epoch:1276  d_loss:0.5775  g_loss:1.8613
# epoch:1277  d_loss:0.7489  g_loss:1.8701
# epoch:1278  d_loss:0.4305  g_loss:2.7697
# epoch:1279  d_loss:0.4144  g_loss:2.9842
# epoch:1280  d_loss:0.4099  g_loss:2.9137
# epoch:1281  d_loss:0.5659  g_loss:1.8095
# epoch:1282  d_loss:0.5187  g_loss:1.6417
# epoch:1283  d_loss:0.3951  g_loss:1.7546
# epoch:1284  d_loss:0.4262  g_loss:2.0359
# epoch:1285  d_loss:0.3487  g_loss:2.2313
# epoch:1286  d_loss:0.4168  g_loss:2.7478
# epoch:1287  d_loss:0.5100  g_loss:2.8221
# epoch:1288  d_loss:0.4076  g_loss:2.2177
# epoch:1289  d_loss:0.4616  g_loss:1.7795
# epoch:1290  d_loss:0.3248  g_loss:1.8974
# epoch:1291  d_loss:0.3717  g_loss:2.0917
# epoch:1292  d_loss:0.3521  g_loss:1.9783
# epoch:1293  d_loss:0.4094  g_loss:2.1373
# epoch:1294  d_loss:0.3408  g_loss:2.4286
# epoch:1295  d_loss:0.3624  g_loss:2.0764
# epoch:1296  d_loss:0.4148  g_loss:2.3973
# epoch:1297  d_loss:0.3520  g_loss:2.3836
# epoch:1298  d_loss:0.2552  g_loss:2.4582
# epoch:1299  d_loss:0.4544  g_loss:2.0777
# epoch:1300  d_loss:0.2447  g_loss:2.4438
# epoch:1301  d_loss:0.6718  g_loss:1.7696
# epoch:1302  d_loss:0.5122  g_loss:1.6549
# epoch:1303  d_loss:0.4406  g_loss:2.0393
# epoch:1304  d_loss:0.4354  g_loss:2.1342
# epoch:1305  d_loss:0.5939  g_loss:2.2219
# epoch:1306  d_loss:0.6380  g_loss:1.2832
# epoch:1307  d_loss:0.4794  g_loss:1.4181
# epoch:1308  d_loss:0.4223  g_loss:1.9552
# epoch:1309  d_loss:0.4336  g_loss:1.9220
# epoch:1310  d_loss:0.3914  g_loss:2.3410
# epoch:1311  d_loss:0.5092  g_loss:2.0440
# epoch:1312  d_loss:0.2690  g_loss:2.0976
# epoch:1313  d_loss:0.4070  g_loss:1.9704
# epoch:1314  d_loss:0.4145  g_loss:1.9517
# epoch:1315  d_loss:0.2926  g_loss:2.2250
# epoch:1316  d_loss:0.3592  g_loss:2.4063
# epoch:1317  d_loss:0.4578  g_loss:1.8056
# epoch:1318  d_loss:0.3614  g_loss:2.1352
# epoch:1319  d_loss:0.2641  g_loss:2.2333
# epoch:1320  d_loss:0.4156  g_loss:2.0730
# epoch:1321  d_loss:0.2812  g_loss:2.0310
# epoch:1322  d_loss:0.2933  g_loss:2.4255
# epoch:1323  d_loss:0.2201  g_loss:2.6795
# epoch:1324  d_loss:0.2479  g_loss:3.0492
# epoch:1325  d_loss:0.2798  g_loss:2.6866
# epoch:1326  d_loss:0.3992  g_loss:2.3927
# epoch:1327  d_loss:0.3739  g_loss:1.7878
# epoch:1328  d_loss:0.4294  g_loss:2.0039
# epoch:1329  d_loss:0.3669  g_loss:2.0590
# epoch:1330  d_loss:0.3005  g_loss:2.1136
# epoch:1331  d_loss:0.2565  g_loss:2.6857
# epoch:1332  d_loss:0.2681  g_loss:2.8137
# epoch:1333  d_loss:0.3893  g_loss:2.3784
# epoch:1334  d_loss:0.5053  g_loss:1.7333
# epoch:1335  d_loss:0.4691  g_loss:1.3182
# epoch:1336  d_loss:0.3293  g_loss:1.4627
# epoch:1337  d_loss:0.4244  g_loss:2.0322
# epoch:1338  d_loss:0.2840  g_loss:2.1194
# epoch:1339  d_loss:0.4864  g_loss:2.5382
# epoch:1340  d_loss:0.4084  g_loss:2.1429
# epoch:1341  d_loss:0.3058  g_loss:1.9739
# epoch:1342  d_loss:0.4947  g_loss:1.7550
# epoch:1343  d_loss:0.4827  g_loss:1.6247
# epoch:1344  d_loss:0.3774  g_loss:1.7347
# epoch:1345  d_loss:0.4744  g_loss:1.7264
# epoch:1346  d_loss:0.4297  g_loss:2.0651
# epoch:1347  d_loss:0.4020  g_loss:2.1096
# epoch:1348  d_loss:0.5441  g_loss:1.6156
# epoch:1349  d_loss:0.5442  g_loss:1.2414
# epoch:1350  d_loss:0.4631  g_loss:1.4103
# epoch:1351  d_loss:0.4443  g_loss:1.8376
# epoch:1352  d_loss:0.3886  g_loss:1.8590
# epoch:1353  d_loss:0.3577  g_loss:2.5721
# epoch:1354  d_loss:0.5538  g_loss:2.3532
# epoch:1355  d_loss:0.3400  g_loss:1.8992
# epoch:1356  d_loss:0.3805  g_loss:1.4950
# epoch:1357  d_loss:0.4892  g_loss:2.0253
# epoch:1358  d_loss:0.3202  g_loss:1.9639
# epoch:1359  d_loss:0.6475  g_loss:1.3491
# epoch:1360  d_loss:0.5326  g_loss:1.7226
# epoch:1361  d_loss:0.3139  g_loss:2.0165
# epoch:1362  d_loss:0.3275  g_loss:2.2194
# epoch:1363  d_loss:0.4134  g_loss:2.4458
# epoch:1364  d_loss:0.4833  g_loss:2.2339
# epoch:1365  d_loss:0.4389  g_loss:1.9014
# epoch:1366  d_loss:0.3322  g_loss:2.0879
# epoch:1367  d_loss:0.5246  g_loss:1.6250
# epoch:1368  d_loss:0.3234  g_loss:1.8171
# epoch:1369  d_loss:0.4182  g_loss:2.0207
# epoch:1370  d_loss:0.3501  g_loss:2.0932
# epoch:1371  d_loss:0.5119  g_loss:2.2628
# epoch:1372  d_loss:0.3503  g_loss:2.2952
# epoch:1373  d_loss:0.3931  g_loss:2.0969
# epoch:1374  d_loss:0.3047  g_loss:1.8435
# epoch:1375  d_loss:0.4479  g_loss:1.6053
# epoch:1376  d_loss:0.5273  g_loss:1.5264
# epoch:1377  d_loss:0.5472  g_loss:1.7595
# epoch:1378  d_loss:0.3063  g_loss:2.2649
# epoch:1379  d_loss:0.3465  g_loss:1.9401
# epoch:1380  d_loss:0.4310  g_loss:2.1602
# epoch:1381  d_loss:0.4659  g_loss:1.8800
# epoch:1382  d_loss:0.3560  g_loss:2.1760
# epoch:1383  d_loss:0.5843  g_loss:2.3597
# epoch:1384  d_loss:0.4178  g_loss:1.9203
# epoch:1385  d_loss:0.4417  g_loss:1.9220
# epoch:1386  d_loss:0.3881  g_loss:1.5369
# epoch:1387  d_loss:0.4358  g_loss:1.5818
# epoch:1388  d_loss:0.5399  g_loss:1.5468
# epoch:1389  d_loss:0.3612  g_loss:1.9173
# epoch:1390  d_loss:0.4592  g_loss:1.8110
# epoch:1391  d_loss:0.5098  g_loss:1.7529
# epoch:1392  d_loss:0.5619  g_loss:1.6242
# epoch:1393  d_loss:0.4491  g_loss:1.7134
# epoch:1394  d_loss:0.4443  g_loss:1.9384
# epoch:1395  d_loss:0.5122  g_loss:1.4628
# epoch:1396  d_loss:0.3788  g_loss:1.6456
# epoch:1397  d_loss:0.5111  g_loss:1.6064
# epoch:1398  d_loss:0.3986  g_loss:1.6647
# epoch:1399  d_loss:0.2950  g_loss:2.2442
# epoch:1400  d_loss:0.4154  g_loss:2.1848
# epoch:1401  d_loss:0.4397  g_loss:2.2617
# epoch:1402  d_loss:0.3943  g_loss:2.1089
# epoch:1403  d_loss:0.4685  g_loss:2.0232
# epoch:1404  d_loss:0.4449  g_loss:1.3208
# epoch:1405  d_loss:0.3849  g_loss:1.4742
# epoch:1406  d_loss:0.3430  g_loss:1.7087
# epoch:1407  d_loss:0.2998  g_loss:2.0816
# epoch:1408  d_loss:0.4426  g_loss:2.1974
# epoch:1409  d_loss:0.3107  g_loss:2.2909
# epoch:1410  d_loss:0.4964  g_loss:1.9590
# epoch:1411  d_loss:0.4056  g_loss:1.9563
# epoch:1412  d_loss:0.3732  g_loss:2.0145
# epoch:1413  d_loss:0.4025  g_loss:1.6702
# epoch:1414  d_loss:0.4121  g_loss:1.6192
# epoch:1415  d_loss:0.3997  g_loss:2.0595
# epoch:1416  d_loss:0.4581  g_loss:1.6687
# epoch:1417  d_loss:0.3615  g_loss:1.8899
# epoch:1418  d_loss:0.4271  g_loss:1.9161
# epoch:1419  d_loss:0.5534  g_loss:1.7264
# epoch:1420  d_loss:0.4277  g_loss:2.0530
# epoch:1421  d_loss:0.5025  g_loss:1.8733
# epoch:1422  d_loss:0.5779  g_loss:1.4627
# epoch:1423  d_loss:0.5964  g_loss:1.2612
# epoch:1424  d_loss:0.4596  g_loss:1.6785
# epoch:1425  d_loss:0.5170  g_loss:1.5931
# epoch:1426  d_loss:0.4082  g_loss:2.0841
# epoch:1427  d_loss:0.4813  g_loss:1.7777
# epoch:1428  d_loss:0.5799  g_loss:1.5292
# epoch:1429  d_loss:0.5149  g_loss:1.7237
# epoch:1430  d_loss:0.5726  g_loss:1.4374
# epoch:1431  d_loss:0.5494  g_loss:1.3484
# epoch:1432  d_loss:0.4997  g_loss:1.6312
# epoch:1433  d_loss:0.5434  g_loss:1.3679
# epoch:1434  d_loss:0.6783  g_loss:1.6719
# epoch:1435  d_loss:0.5053  g_loss:1.4823
# epoch:1436  d_loss:0.4725  g_loss:1.5849
# epoch:1437  d_loss:0.4605  g_loss:1.8434
# epoch:1438  d_loss:0.4114  g_loss:1.5763
# epoch:1439  d_loss:0.5621  g_loss:1.8247
# epoch:1440  d_loss:0.5097  g_loss:1.4626
# epoch:1441  d_loss:0.5131  g_loss:1.4643
# epoch:1442  d_loss:0.4348  g_loss:1.6417
# epoch:1443  d_loss:0.4911  g_loss:1.8025
# epoch:1444  d_loss:0.3629  g_loss:2.1901
# epoch:1445  d_loss:0.4025  g_loss:2.2736
# epoch:1446  d_loss:0.4002  g_loss:1.9181
# epoch:1447  d_loss:0.4510  g_loss:1.6741
# epoch:1448  d_loss:0.3477  g_loss:1.5513
# epoch:1449  d_loss:0.4867  g_loss:1.4410
# epoch:1450  d_loss:0.3152  g_loss:1.9081
# epoch:1451  d_loss:0.3983  g_loss:2.0968
# epoch:1452  d_loss:0.4832  g_loss:2.1029
# epoch:1453  d_loss:0.5639  g_loss:1.7495
# epoch:1454  d_loss:0.4523  g_loss:1.2636
# epoch:1455  d_loss:0.4396  g_loss:1.9681
# epoch:1456  d_loss:0.4162  g_loss:1.5003
# epoch:1457  d_loss:0.5182  g_loss:1.7101
# epoch:1458  d_loss:0.5369  g_loss:1.8322
# epoch:1459  d_loss:0.5620  g_loss:1.5284
# epoch:1460  d_loss:0.4497  g_loss:1.6392
# epoch:1461  d_loss:0.5230  g_loss:1.7364
# epoch:1462  d_loss:0.4453  g_loss:1.7566
# epoch:1463  d_loss:0.5396  g_loss:1.7875
# epoch:1464  d_loss:0.3887  g_loss:1.5529
# epoch:1465  d_loss:0.4608  g_loss:1.5357
# epoch:1466  d_loss:0.4774  g_loss:1.4974
# epoch:1467  d_loss:0.4506  g_loss:1.5355
# epoch:1468  d_loss:0.5636  g_loss:1.2468
# epoch:1469  d_loss:0.3982  g_loss:1.8018
# epoch:1470  d_loss:0.4165  g_loss:2.0800
# epoch:1471  d_loss:0.3978  g_loss:1.8895
# epoch:1472  d_loss:0.5943  g_loss:1.7621
# epoch:1473  d_loss:0.6308  g_loss:1.3175
# epoch:1474  d_loss:0.4650  g_loss:1.3111
# epoch:1475  d_loss:0.4995  g_loss:1.3719
# epoch:1476  d_loss:0.4398  g_loss:1.7696
# epoch:1477  d_loss:0.4110  g_loss:1.8117
# epoch:1478  d_loss:0.5868  g_loss:1.3427
# epoch:1479  d_loss:0.3376  g_loss:1.6161
# epoch:1480  d_loss:0.2712  g_loss:1.7903
# epoch:1481  d_loss:0.3983  g_loss:1.9822
# epoch:1482  d_loss:0.3280  g_loss:1.7304
# epoch:1483  d_loss:0.3925  g_loss:1.7786
# epoch:1484  d_loss:0.4053  g_loss:1.8843
# epoch:1485  d_loss:0.3843  g_loss:1.7219
# epoch:1486  d_loss:0.3429  g_loss:2.0892
# epoch:1487  d_loss:0.2584  g_loss:2.1784
# epoch:1488  d_loss:0.3550  g_loss:2.5637
# epoch:1489  d_loss:0.3987  g_loss:1.9042
# epoch:1490  d_loss:0.4461  g_loss:1.5707
# epoch:1491  d_loss:0.4465  g_loss:1.5913
# epoch:1492  d_loss:0.4914  g_loss:1.4920
# epoch:1493  d_loss:0.3426  g_loss:1.6385
# epoch:1494  d_loss:0.3733  g_loss:2.0827
# epoch:1495  d_loss:0.3014  g_loss:2.4019
# epoch:1496  d_loss:0.4435  g_loss:1.7782
# epoch:1497  d_loss:0.4159  g_loss:1.5595
# epoch:1498  d_loss:0.4397  g_loss:1.9074
# epoch:1499  d_loss:0.2701  g_loss:2.0168
# epoch:1500  d_loss:0.4546  g_loss:1.6042
# epoch:1501  d_loss:0.4970  g_loss:1.5435
# epoch:1502  d_loss:0.5146  g_loss:1.5865
# epoch:1503  d_loss:0.6078  g_loss:1.8700
# epoch:1504  d_loss:0.5230  g_loss:1.8083
# epoch:1505  d_loss:0.5366  g_loss:1.8555
# epoch:1506  d_loss:0.4635  g_loss:2.0814
# epoch:1507  d_loss:0.6897  g_loss:1.8292
# epoch:1508  d_loss:0.5688  g_loss:1.5005
# epoch:1509  d_loss:0.5365  g_loss:1.1660
# epoch:1510  d_loss:0.4284  g_loss:1.1996
# epoch:1511  d_loss:0.5372  g_loss:1.3697
# epoch:1512  d_loss:0.5322  g_loss:1.6264
# epoch:1513  d_loss:0.4923  g_loss:2.1311
# epoch:1514  d_loss:0.4721  g_loss:1.9770
# epoch:1515  d_loss:0.4756  g_loss:1.8183
# epoch:1516  d_loss:0.5602  g_loss:1.5227
# epoch:1517  d_loss:0.5828  g_loss:1.4230
# epoch:1518  d_loss:0.3643  g_loss:1.9626
# epoch:1519  d_loss:0.4290  g_loss:2.3157
# epoch:1520  d_loss:0.5765  g_loss:1.8887
# epoch:1521  d_loss:0.3631  g_loss:1.8365
# epoch:1522  d_loss:0.3673  g_loss:1.8471
# epoch:1523  d_loss:0.4989  g_loss:1.8444
# epoch:1524  d_loss:0.4248  g_loss:2.1363
# epoch:1525  d_loss:0.4427  g_loss:2.0102

# %%
np.zeros((batch_size , 0))
